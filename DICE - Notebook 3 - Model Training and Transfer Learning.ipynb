# %% [markdown]
# # DICE - Notebook 2 - Dataset Preparation
#
# <br/>
#
# ```
# *************************************************************************
# **
# ** 2017 Mai 23
# **
# ** In place of a legal notice, here is a blessing:
# **
# **    May you do good and not evil.
# **    May you find forgiveness for yourself and forgive others.
# **    May you share freely, never taking more than you give.
# **
# *************************************************************************
# ```
#
# <table style="width:100%; font-size:14px; margin: 20px 0;">
#     <tr>
#         <td style="text-align:center">
#             <b>Contact: </b><a href="mailto:contact@jonathandekhtiar.eu" target="_blank">contact@jonathandekhtiar.eu</a>
#         </td>
#         <td style="text-align:center">
#             <b>Twitter: </b><a href="https://twitter.com/born2data" target="_blank">@born2data</a>
#         </td>
#         <td style="text-align:center">
#             <b>Tech. Blog: </b><a href="http://www.born2data.com/" target="_blank">born2data.com</a>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align:center">
#             <b>Personal Website: </b><a href="http://www.jonathandekhtiar.eu" target="_blank">jonathandekhtiar.eu</a>
#         </td>
#         <td style="text-align:center">
#             <b>RSS Feed: </b><a href="https://www.feedcrunch.io/@dataradar/" target="_blank">FeedCrunch.io</a>
#         </td>
#         <td style="text-align:center">
#             <b>LinkedIn: </b><a href="https://fr.linkedin.com/in/jonathandekhtiar" target="_blank">JonathanDEKHTIAR</a>
#         </td>
#     </tr>
# </table>
#
# ## Objectives
#
# This notebook aims to preprocess and prepare the dataset for later used during the training phase.
#
# There exists many methods to feed data into a Deep Learning with [Tensorflow](https://www.tensorflow.org/), the Python Library we have chosen to use for this study:
#
# 1. **From Disk**: Data can be inputed into a model with the **feed_dict** argument when running a *training operation*. It would  definitely be possible, however this process can be slow if there are a lot of data to read simultaneously and could be too large to be held in the GPU Memory.
# <br><br>
# 2. **From a CSV File**: This [type of file](https://en.wikipedia.org/wiki/Comma-separated_values) is not revelant when dealing with images.
# <br><br>
# 3. **From a preprocessed binary file**: Tensorflow is able to save and recover data in a binary format called [TFRecords](https://www.tensorflow.org/api_guides/python/python_io#TFRecords_Format_Details). The data can be preprocessed beforehand and only the necessary data can be saved and read in real time during the training. This approach is the fatest and most memory-efficient when dealing with images.
#
# This notebook will focus on generating the necessary **TFRecord** files. Generating **TFRecords** is less intuitive than
# [HDF5](https://en.wikipedia.org/wiki/Hierarchical_Data_Format), used in other Deep Learning libraries such as [Keras](https://keras.io/). Using **TFRecords** will give you access to natively available tools, such as *Queue Runners*, *Coordinators*, *Supervisors*, *etc.*, to design [data pipelines](https://www.tensorflow.org/programmers_guide/reading_data) and process the images in a batch fashion.
#
# This notebook will use [Tensorflow-Slim](https://github.com/tensorflow/tensorflow/tree/master/tensorflow/contrib/slim) to ease the understanding and reduce the code complexity.
#
# As we aim to to later re-train a CNN Model
#
# This will be used later to retrain an CNN model: [Inception-V4](https://arxiv.org/abs/1602.07261) model developed by Szegedy et al. The model has been Pre-Trained with the [ImageNet](http://www.image-net.org/) dataset allowing a much more accurate result due to the large number of data avaiable in this dataset. We call this kind of process: "*Transfer Learning*".
#
#
# This notebook will also randomly split the available data into two sets of data: [Training and Validation sets](https://stats.stackexchange.com/questions/19048/what-is-the-difference-between-test-set-and-validation-set). This process aims to reduce the [overfit](http://scikit-learn.org/stable/auto_examples/model_selection/plot_underfitting_overfitting.html) of the model and thus improving its accuracy on previously unseen data.
#
# In this study the selection ratio has been chosen as followed:
# - *training set:* 60%
# - *validation set:* 40%.
#
# ---
#
# As reminder before starting, the data have already been preprocessed (resized, augmented, etc.) in the first Notebook: **[DICE - Notebook 1 - Dataset Augmentation](https://github.com/DEKHTIARJonathan/DICE-DMU_Imagery_Classification_Engine/blob/master/DICE%20-%20Notebook%201%20-%20Dataset%20Augmentation.ipynb)**
#
# The preprocessed data all have been saved as **JPEG images** and thus we will only focus on these data.
#
# ## 1. Notebook Initialisation
#
# ### 1.1. Load the necessary libraries

# %%
import os, time, math

import tensorflow as tf
from tensorflow.contrib.framework.python.ops.variables import get_or_create_global_step
from tensorflow.python.platform import tf_logging as logging

import inception_preprocessing
from inception_resnet_v2 import inception_resnet_v2, inception_resnet_v2_arg_scope

slim = tf.contrib.slim

# %%
#================ DATASET INFORMATION ======================
#State dataset directory where the tfrecord files are located
dataset_dir = 'data_prepared/'

#State where your log file is at. If it doesn't exist, create it.
log_dir = 'log/'

#Create the log directory here. Must be done here otherwise import will activate this unneededly.
if not os.path.exists(log_dir):
    os.mkdir(log_dir)

#State where your checkpoint file is
checkpoint_file = 'model/inception_resnet_v2_2016_08_30.ckpt'

#State the image size you're resizing your images to. We will use the default inception size of 299.
image_size = 299

#State the number of classes to predict:
num_classes = 5

#State the labels file and read it
labels_file = 'data_prepared/labels.txt'
labels = open(labels_file, 'r')

#Create a dictionary to refer each label to their string name
labels_to_name = {}
for line in labels:
    label, string_name = line.split(':')
    string_name = string_name[:-1] #Remove newline
    labels_to_name[int(label)] = string_name

#Create the file pattern of your TFRecord files so that it could be recognized later on
tf_record_start_name = 'dmunet_dataset_'
file_pattern = tf_record_start_name + '%s_*.tfrecord'

#Create a dictionary that will help people understand your dataset better. This is required by the Dataset class later.
items_to_descriptions = {
    'image': 'A 3-channel RGB coloured flower image that is either tulips, sunflowers, roses, dandelion, or daisy.',
    'label': 'A label that is as such -- 0:daisy, 1:dandelion, 2:roses, 3:sunflowers, 4:tulips'
}

tf.logging.set_verbosity(tf.logging.INFO) #Set the verbosity to INFO level

#================= TRAINING INFORMATION ==================
#State the number of epochs to train
num_epochs = 30

#State your batch size => Choose the highest value which doesn't give you a memory error.
batch_size = 14

#Learning rate information and configuration (Up to you to experiment)
initial_learning_rate = 0.0002
learning_rate_decay_factor = 0.7
num_epochs_before_decay = 2

# %%
#============== DATASET LOADING ======================
#We now create a function that creates a Dataset class which will give us many TFRecord files to feed in the examples into a queue in parallel.
def get_split(split_name, dataset_dir, file_pattern=file_pattern):
    '''
    Obtains the split - training or validation - to create a Dataset class for feeding the examples into a queue later on. This function will
    set up the decoder and dataset information all into one Dataset class so that you can avoid the brute work later on.
    Your file_pattern is very important in locating the files later. 

    INPUTS:
    - split_name(str): 'train' or 'validation'. Used to get the correct data split of tfrecord files
    - dataset_dir(str): the dataset directory where the tfrecord files are located
    - file_pattern(str): the file name structure of the tfrecord files in order to get the correct data

    OUTPUTS:
    - dataset (Dataset): A Dataset class object where we can read its various components for easier batch creation later.
    '''

    #First check whether the split_name is train or validation
    if split_name not in ['train', 'validation']:
        raise ValueError('The split_name %s is not recognized. Please input either train or validation as the split_name' % (split_name))

    #Create the full path for a general file_pattern to locate the tfrecord_files
    file_pattern_path = os.path.join(dataset_dir, file_pattern % (split_name))

    #Count the total number of examples in all of these shard
    num_samples = 0
    file_pattern_for_counting = tf_record_start_name + split_name
    tfrecords_to_count = [os.path.join(dataset_dir, file) for file in os.listdir(dataset_dir) if file.startswith(file_pattern_for_counting)]
    for tfrecord_file in tfrecords_to_count:
        for record in tf.python_io.tf_record_iterator(tfrecord_file):
            num_samples += 1

    #Create a reader, which must be a TFRecord reader in this case
    reader = tf.TFRecordReader

    #Create the keys_to_features dictionary for the decoder
    keys_to_features = {
      'image/encoded': tf.FixedLenFeature((), tf.string, default_value=''),
      'image/format': tf.FixedLenFeature((), tf.string, default_value='jpg'),
      'image/class/label': tf.FixedLenFeature(
          [], tf.int64, default_value=tf.zeros([], dtype=tf.int64)),
    }

    #Create the items_to_handlers dictionary for the decoder.
    items_to_handlers = {
    'image': slim.tfexample_decoder.Image(),
    'label': slim.tfexample_decoder.Tensor('image/class/label'),
    }

    #Start to create the decoder
    decoder = slim.tfexample_decoder.TFExampleDecoder(keys_to_features, items_to_handlers)

    #Create the labels_to_name file
    labels_to_name_dict = labels_to_name

    #Actually create the dataset
    dataset = slim.dataset.Dataset(
        data_sources = file_pattern_path,
        decoder = decoder,
        reader = reader,
        num_readers = 4,
        num_samples = num_samples,
        num_classes = num_classes,
        labels_to_name = labels_to_name_dict,
        items_to_descriptions = items_to_descriptions)

    return dataset

# %%
def load_batch(dataset, batch_size, height=image_size, width=image_size, is_training=True):
    '''
    Loads a batch for training.

    INPUTS:
    - dataset(Dataset): a Dataset class object that is created from the get_split function
    - batch_size(int): determines how big of a batch to train
    - height(int): the height of the image to resize to during preprocessing
    - width(int): the width of the image to resize to during preprocessing
    - is_training(bool): to determine whether to perform a training or evaluation preprocessing

    OUTPUTS:
    - images(Tensor): a Tensor of the shape (batch_size, height, width, channels) that contain one batch of images
    - labels(Tensor): the batch's labels with the shape (batch_size,) (requires one_hot_encoding).

    '''
    #First create the data_provider object
    data_provider = slim.dataset_data_provider.DatasetDataProvider(
        dataset,
        common_queue_capacity = 24 + 3 * batch_size,
        common_queue_min = 24)

    #Obtain the raw image using the get method
    raw_image, label = data_provider.get(['image', 'label'])

    #Perform the correct preprocessing for this image depending if it is training or evaluating
    image = inception_preprocessing.preprocess_image(raw_image, height, width, is_training)

    #As for the raw images, we just do a simple reshape to batch it up
    raw_image = tf.expand_dims(raw_image, 0)
    raw_image = tf.image.resize_nearest_neighbor(raw_image, [height, width])
    raw_image = tf.squeeze(raw_image)

    #Batch up the image by enqueing the tensors internally in a FIFO queue and dequeueing many elements with tf.train.batch.
    images, raw_images, labels = tf.train.batch(
        [image, raw_image, label],
        batch_size = batch_size,
        num_threads = 4,
        capacity = 4 * batch_size,
        allow_smaller_final_batch = True)

    return images, raw_images, labels

# %% [markdown]
# ### Loading dataset and data batches

# %%
dataset = get_split('train', dataset_dir, file_pattern=file_pattern)
images, _, labels = load_batch(dataset, batch_size=batch_size)

num_batches_per_epoch = tf.cast(tf.ceil(dataset.num_samples / batch_size), tf.int32)

#Know the number steps to take before decaying the learning rate and batches per epoch
num_steps_per_epoch = num_batches_per_epoch #Because one step is one batch processed
decay_steps = tf.cast(num_epochs_before_decay * num_steps_per_epoch, tf.int32)

# %%
#Create the model inference
with slim.arg_scope(inception_resnet_v2_arg_scope()):
    logits, end_points = inception_resnet_v2(images, num_classes = dataset.num_classes, is_training = True)

# %%
#Define the scopes that you want to exclude for restoration
exclude = ['InceptionResnetV2/Logits', 'InceptionResnetV2/AuxLogits']
variables_to_restore = slim.get_variables_to_restore(exclude = exclude)

# %%
#Perform one-hot-encoding of the labels (Try one-hot-encoding within the load_batch function!)
one_hot_labels = slim.one_hot_encoding(labels, dataset.num_classes)

# %%
#Performs the equivalent to tf.nn.sparse_softmax_cross_entropy_with_logits but enhanced with checks
loss = tf.losses.softmax_cross_entropy(onehot_labels = one_hot_labels, logits = logits)
total_loss = tf.losses.get_total_loss()    #obtain the regularization losses as well

# %%
#Create the global step for monitoring the learning_rate and training.
global_step = get_or_create_global_step()

# %%
#Define your exponentially decaying learning rate
lr = tf.train.exponential_decay(
    learning_rate = initial_learning_rate,
    global_step = global_step,
    decay_steps = decay_steps,
    decay_rate = learning_rate_decay_factor,
    staircase = True
)

# %%
#Now we can define the optimizer that takes on the learning rate
optimizer = tf.train.AdamOptimizer(learning_rate = lr)

# %%
#Create the train_op.
train_op = slim.learning.create_train_op(total_loss, optimizer)

# %%
#State the metrics that you want to predict. We get a predictions that is not one_hot_encoded.
predictions = tf.argmax(end_points['Predictions'], 1)
probabilities = end_points['Predictions']
accuracy, accuracy_update = tf.contrib.metrics.streaming_accuracy(predictions, labels)
metrics_op = tf.group(accuracy_update, probabilities)

# %%
#Now finally create all the summaries you need to monitor and group them into one summary op.
tf.summary.scalar('losses/Total_Loss', total_loss)
tf.summary.scalar('accuracy', accuracy)
tf.summary.scalar('learning_rate', lr)
my_summary_op = tf.summary.merge_all()

# %%
#Now we need to create a training step function that runs both the train_op, metrics_op and updates the global_step concurrently.
def train_step(sess, train_op, global_step):
    '''
    Simply runs a session for the three arguments provided and gives a logging on the time elapsed for each global step
    '''
    #Check the time for each sess run
    start_time = time.time()
    total_loss, global_step_count, _ = sess.run([train_op, global_step, metrics_op])
    time_elapsed = time.time() - start_time

    #Run the logging to print some results
    logging.info('global step %s: loss: %.4f (%.2f sec/step)', global_step_count, total_loss, time_elapsed)

    return total_loss, global_step_count

# %%
#Now we create a saver function that actually restores the variables from a checkpoint file in a sess
saver = tf.train.Saver(variables_to_restore)
def restore_fn(sess):
    return saver.restore(sess, checkpoint_file)

# %%
#Define your supervisor for running a managed session. 
#Do not run the summary_op automatically or else it will consume too much memory

sv = tf.train.Supervisor(logdir = log_dir, summary_op = None, init_fn = restore_fn)

# %%
#Run the managed session
with sv.managed_session() as sess:
    
    _num_steps_per_epoch, _num_batches_per_epoch = sess.run([num_steps_per_epoch, num_batches_per_epoch])    
    
    print("num_steps_per_epoch:", _num_steps_per_epoch)  
    print("num_batches_per_epoch:", _num_batches_per_epoch)
    print("num_epochs:", num_epochs)
    
    print("total:", _num_steps_per_epoch * num_epochs)
    
    for step in range(_num_steps_per_epoch * num_epochs):
        
        #At the start of every epoch, show the vital information:
        if step % _num_batches_per_epoch == 0:
            logging.info('Epoch %s/%s', step/_num_batches_per_epoch + 1, num_epochs)
            learning_rate_value, accuracy_value = sess.run([lr, accuracy])
            logging.info('Current Learning Rate: %s', learning_rate_value)
            logging.info('Current Streaming Accuracy: %s', accuracy_value)

            # optionally, print your logits and predictions for a sanity check that things are going fine.
            logits_value, probabilities_value, predictions_value, labels_value = sess.run([
                logits, 
                probabilities, 
                predictions, 
                labels
            ])
            
            print ('logits: \n', logits_value)
            print ('Probabilities: \n', probabilities_value)
            print ('predictions: \n', predictions_value)
            print ('Labels:\n:', labels_value)

        #Log the summaries every 10 step.
        if step % 10 == 0:
            loss, _ = train_step(sess, train_op, sv.global_step)
            summaries = sess.run(my_summary_op)
            sv.summary_computed(sess, summaries)

        #If not, simply run the training step
        else:
            loss, _ = train_step(sess, train_op, sv.global_step)

    #We log the final training loss and accuracy
    logging.info('Final Loss: %s', loss)
    logging.info('Final Accuracy: %s', sess.run(accuracy))

    #Once all the training has been done, save the log files and checkpoint model
    logging.info('Finished training! Saving model to disk now.')
    # saver.save(sess, "./flowers_model.ckpt")
    sv.saver.save(sess, sv.save_path, global_step = sv.global_step)
# Out:
# INFO:tensorflow:Restoring parameters from log/model.ckpt-0
# INFO:tensorflow:global_step/sec: 0
# num_steps_per_epoch: 4876
# num_batches_per_epoch: 4876
# num_epochs: 30
# total: 146280
# INFO:tensorflow:Epoch 1.0/30
# INFO:tensorflow:Current Learning Rate: 0.0002
# INFO:tensorflow:Current Streaming Accuracy: 0.0
# logits:
#  [[-0.77252555  0.4478153  -0.018868    0.16657667 -0.05937041]
#  [-0.6278286  -0.29029846 -0.20948823 -0.24767564 -0.27595681]
#  [-0.11307829 -0.04914204 -0.67847419 -0.54170096 -0.48865983]
#  [-0.86079305 -0.49302948  0.4180305   0.58822399 -0.48470998]
#  [-0.79382354  0.2182719  -0.12678927  0.59697485  0.06259594]
#  [-0.39356339 -0.67539716  0.37656036  0.3637068  -1.06576049]
#  [-0.53375268  0.02022753 -0.2114595  -0.01591312 -0.71770221]
#  [-0.3647446  -0.70912516  0.18293066  0.75264382 -0.15489998]
#  [-0.49692446  0.32737732 -0.06713459 -0.08677792 -0.32306647]
#  [-0.29924527  0.34148335 -0.28721502 -0.081971   -0.45514295]
#  [-0.31555846 -0.192754   -0.51218784  0.59839284 -0.98032707]
#  [-0.22141197  0.3137832   0.3952868   0.08053286 -0.28981313]
#  [-0.07891299 -0.07541504 -0.12428948  0.00272609 -0.41185394]
#  [-0.71001565 -0.73067826 -0.28482443  0.33317831  0.27754295]]
# Probabilities:
#  [[ 0.08999926  0.30494833  0.19122659  0.23018971  0.1836362 ]
#  [ 0.14694744  0.20594418  0.22327749  0.21491186  0.20891902]
#  [ 0.25173351  0.26835406  0.14301865  0.16398063  0.17291315]
#  [ 0.08508897  0.12291104  0.30567452  0.36238763  0.12393788]
#  [ 0.08283233  0.22790155  0.16139464  0.33282498  0.19504645]
#  [ 0.15249798  0.11504432  0.32940072  0.32519385  0.07786325]
#  [ 0.15081067  0.26243553  0.20816238  0.25312027  0.12547113]
#  [ 0.12939566  0.09169742  0.22375464  0.3955445   0.15960778]
#  [ 0.13308229  0.30346596  0.20453878  0.20056015  0.15835282]
#  [ 0.16643649  0.31587368  0.16845085  0.2068281   0.14241083]
#  [ 0.16776527  0.18968603  0.13781834  0.41843316  0.08629721]
#  [ 0.14605033  0.24942203  0.27060226  0.1975311   0.13639431]
#  [ 0.21003911  0.21077511  0.20072126  0.2279059   0.15055867]
#  [ 0.11071289  0.10844874  0.16937774  0.31423283  0.29722777]]
# predictions:
#  [1 2 1 3 3 2 1 3 1 1 3 2 3 3]
# Labels:
# : [2 4 1 2 4 4 3 4 0 3 3 1 1 1]
# INFO:tensorflow:global step 1: loss: 2.2068 (6.22 sec/step)
# INFO:tensorflow:global step 2: loss: 2.1311 (1.23 sec/step)
# INFO:tensorflow:global step 3: loss: 1.9632 (1.23 sec/step)
# INFO:tensorflow:global step 4: loss: 2.0381 (1.24 sec/step)
# INFO:tensorflow:global step 5: loss: 2.0997 (1.24 sec/step)
# INFO:tensorflow:global step 6: loss: 1.7125 (1.23 sec/step)
# INFO:tensorflow:global step 7: loss: 1.6872 (3.90 sec/step)
# INFO:tensorflow:global step 8: loss: 1.3915 (1.24 sec/step)
# INFO:tensorflow:global step 9: loss: 1.7145 (1.25 sec/step)
# INFO:tensorflow:global step 10: loss: 1.3866 (1.23 sec/step)
# INFO:tensorflow:global step 11: loss: 1.2329 (1.24 sec/step)
# INFO:tensorflow:global step 12: loss: 1.1696 (1.23 sec/step)
# INFO:tensorflow:global step 13: loss: 1.2837 (4.59 sec/step)
# INFO:tensorflow:global step 14: loss: 1.0355 (1.24 sec/step)
# INFO:tensorflow:global step 15: loss: 1.0053 (1.24 sec/step)
# INFO:tensorflow:global step 16: loss: 1.0757 (1.23 sec/step)
# INFO:tensorflow:global step 17: loss: 1.2228 (1.23 sec/step)
# INFO:tensorflow:global step 18: loss: 1.1579 (1.23 sec/step)
# INFO:tensorflow:global step 19: loss: 1.1531 (1.23 sec/step)
# INFO:tensorflow:global step 20: loss: 0.9304 (1.23 sec/step)
# INFO:tensorflow:global step 21: loss: 1.6525 (1.24 sec/step)
# INFO:tensorflow:global step 22: loss: 0.9332 (1.24 sec/step)
# INFO:tensorflow:global step 23: loss: 1.6498 (1.24 sec/step)
# INFO:tensorflow:global step 24: loss: 1.8973 (1.23 sec/step)
# INFO:tensorflow:global step 25: loss: 1.8032 (1.23 sec/step)
# INFO:tensorflow:global step 26: loss: 1.5739 (1.24 sec/step)
# INFO:tensorflow:global step 27: loss: 1.5009 (1.23 sec/step)
# INFO:tensorflow:global step 28: loss: 1.6651 (1.23 sec/step)
# INFO:tensorflow:global step 29: loss: 1.3866 (1.23 sec/step)
# INFO:tensorflow:global step 30: loss: 1.6439 (1.23 sec/step)
# INFO:tensorflow:global step 31: loss: 1.3897 (1.23 sec/step)
# INFO:tensorflow:global step 32: loss: 1.9846 (1.23 sec/step)
# INFO:tensorflow:global step 33: loss: 1.2561 (1.23 sec/step)
# INFO:tensorflow:global step 34: loss: 1.7151 (1.23 sec/step)
# INFO:tensorflow:global step 35: loss: 1.7984 (1.24 sec/step)
# INFO:tensorflow:global step 36: loss: 1.3729 (1.24 sec/step)
# INFO:tensorflow:global step 37: loss: 1.3636 (1.23 sec/step)
# INFO:tensorflow:global step 38: loss: 1.3838 (1.23 sec/step)
# INFO:tensorflow:global step 39: loss: 1.2567 (1.23 sec/step)
# INFO:tensorflow:global step 40: loss: 1.3757 (1.23 sec/step)
# INFO:tensorflow:global step 41: loss: 0.8710 (1.23 sec/step)
# INFO:tensorflow:global step 42: loss: 1.0687 (1.24 sec/step)
# INFO:tensorflow:global step 43: loss: 0.8741 (1.23 sec/step)
# INFO:tensorflow:global step 44: loss: 1.0513 (1.25 sec/step)
# INFO:tensorflow:global step 45: loss: 1.0526 (1.25 sec/step)
# INFO:tensorflow:global step 46: loss: 1.3932 (1.25 sec/step)
# INFO:tensorflow:global step 47: loss: 0.8594 (1.25 sec/step)
# INFO:tensorflow:global step 48: loss: 1.0874 (1.24 sec/step)
# INFO:tensorflow:global step 49: loss: 1.0970 (1.25 sec/step)
# INFO:tensorflow:global step 50: loss: 0.9004 (1.25 sec/step)
# INFO:tensorflow:global step 51: loss: 1.2723 (1.25 sec/step)
# INFO:tensorflow:global step 52: loss: 1.5550 (1.25 sec/step)
# INFO:tensorflow:global step 53: loss: 1.3569 (1.25 sec/step)
# INFO:tensorflow:global step 54: loss: 1.2804 (1.25 sec/step)
# INFO:tensorflow:global step 55: loss: 1.2565 (1.24 sec/step)
# INFO:tensorflow:global step 56: loss: 0.8753 (1.25 sec/step)
# INFO:tensorflow:global step 57: loss: 1.3432 (1.25 sec/step)
# INFO:tensorflow:global step 58: loss: 1.8712 (1.25 sec/step)
# INFO:tensorflow:global step 59: loss: 0.7870 (1.25 sec/step)
# INFO:tensorflow:global step 60: loss: 0.8965 (1.25 sec/step)
# INFO:tensorflow:global step 61: loss: 1.0572 (1.31 sec/step)
# INFO:tensorflow:global step 62: loss: 0.9862 (1.32 sec/step)
# INFO:tensorflow:global step 63: loss: 1.1831 (1.31 sec/step)
# INFO:tensorflow:global step 64: loss: 1.0063 (1.29 sec/step)
# INFO:tensorflow:global step 65: loss: 0.8150 (1.31 sec/step)
# INFO:tensorflow:global step 66: loss: 0.8675 (1.30 sec/step)
# INFO:tensorflow:global step 67: loss: 0.9179 (1.30 sec/step)
# INFO:tensorflow:global step 68: loss: 1.0315 (1.29 sec/step)
# INFO:tensorflow:global step 69: loss: 0.7905 (1.31 sec/step)
# INFO:tensorflow:global step 70: loss: 1.2142 (1.30 sec/step)
# INFO:tensorflow:global step 71: loss: 1.4389 (1.30 sec/step)
# INFO:tensorflow:global step 72: loss: 0.7863 (1.31 sec/step)
# INFO:tensorflow:global step 73: loss: 1.1636 (1.31 sec/step)
# INFO:tensorflow:global step 74: loss: 1.0506 (1.30 sec/step)
# INFO:tensorflow:global step 75: loss: 0.8812 (1.30 sec/step)
# INFO:tensorflow:global step 76: loss: 1.2499 (1.31 sec/step)
# INFO:tensorflow:global step 77: loss: 1.2271 (1.31 sec/step)
# INFO:tensorflow:global step 78: loss: 1.3799 (1.33 sec/step)
# INFO:tensorflow:global_step/sec: 0.649943
# INFO:tensorflow:global step 79: loss: 1.3310 (1.30 sec/step)
# INFO:tensorflow:global step 80: loss: 1.3344 (1.30 sec/step)
# INFO:tensorflow:global step 81: loss: 0.8685 (1.31 sec/step)
# INFO:tensorflow:global step 82: loss: 0.9156 (1.30 sec/step)
# INFO:tensorflow:global step 83: loss: 1.3423 (1.33 sec/step)
# INFO:tensorflow:global step 84: loss: 0.8658 (1.31 sec/step)
# INFO:tensorflow:global step 85: loss: 1.0618 (1.32 sec/step)
# INFO:tensorflow:global step 86: loss: 1.1509 (1.32 sec/step)
# INFO:tensorflow:global step 87: loss: 1.0666 (1.32 sec/step)
# INFO:tensorflow:global step 88: loss: 0.9036 (1.33 sec/step)
# INFO:tensorflow:global step 89: loss: 1.2510 (1.34 sec/step)
# INFO:tensorflow:global step 90: loss: 0.8504 (1.33 sec/step)
# INFO:tensorflow:global step 91: loss: 0.6875 (1.35 sec/step)
# INFO:tensorflow:global step 92: loss: 0.9965 (1.35 sec/step)
# INFO:tensorflow:global step 93: loss: 1.7850 (1.33 sec/step)
# INFO:tensorflow:global step 94: loss: 0.8169 (1.33 sec/step)
# INFO:tensorflow:global step 95: loss: 1.0224 (1.33 sec/step)
# INFO:tensorflow:global step 96: loss: 0.7095 (1.33 sec/step)
# INFO:tensorflow:global step 97: loss: 1.3137 (1.33 sec/step)
# INFO:tensorflow:global step 98: loss: 0.9586 (1.33 sec/step)
# INFO:tensorflow:global step 99: loss: 1.0022 (1.33 sec/step)
# INFO:tensorflow:global step 100: loss: 1.0641 (1.33 sec/step)
# INFO:tensorflow:global step 101: loss: 0.8401 (1.33 sec/step)
# INFO:tensorflow:global step 102: loss: 0.9995 (1.33 sec/step)
# INFO:tensorflow:global step 103: loss: 0.7136 (1.33 sec/step)
# INFO:tensorflow:global step 104: loss: 0.7198 (1.33 sec/step)
# INFO:tensorflow:global step 105: loss: 0.9946 (1.33 sec/step)
# INFO:tensorflow:global step 106: loss: 1.4333 (1.33 sec/step)
# INFO:tensorflow:global step 107: loss: 1.2442 (1.33 sec/step)
# INFO:tensorflow:global step 108: loss: 1.1548 (1.33 sec/step)
# INFO:tensorflow:global step 109: loss: 1.3021 (1.32 sec/step)
# INFO:tensorflow:global step 110: loss: 1.5445 (1.33 sec/step)
# INFO:tensorflow:global step 111: loss: 1.1017 (1.32 sec/step)
# INFO:tensorflow:global step 112: loss: 1.0193 (1.34 sec/step)
# INFO:tensorflow:global step 113: loss: 0.8750 (1.33 sec/step)
# INFO:tensorflow:global step 114: loss: 0.8778 (1.33 sec/step)
# INFO:tensorflow:global step 115: loss: 0.9003 (1.32 sec/step)
# INFO:tensorflow:global step 116: loss: 1.0904 (1.33 sec/step)
# INFO:tensorflow:global step 117: loss: 0.9913 (1.33 sec/step)
# INFO:tensorflow:global step 118: loss: 1.0030 (1.35 sec/step)
# INFO:tensorflow:global step 119: loss: 1.1313 (1.35 sec/step)
# INFO:tensorflow:global step 120: loss: 0.7103 (1.34 sec/step)
# INFO:tensorflow:global step 121: loss: 1.2102 (1.34 sec/step)
# INFO:tensorflow:global step 122: loss: 0.9971 (1.34 sec/step)
# INFO:tensorflow:global step 123: loss: 1.1238 (1.35 sec/step)
# INFO:tensorflow:global step 124: loss: 0.9024 (1.35 sec/step)
# INFO:tensorflow:global step 125: loss: 0.9353 (1.34 sec/step)
# INFO:tensorflow:global step 126: loss: 0.9772 (1.34 sec/step)
# INFO:tensorflow:global step 127: loss: 1.0879 (1.34 sec/step)
# INFO:tensorflow:global step 128: loss: 1.2688 (1.34 sec/step)
# INFO:tensorflow:global step 129: loss: 0.7476 (1.34 sec/step)
# INFO:tensorflow:global step 130: loss: 1.2300 (1.35 sec/step)
# INFO:tensorflow:global step 131: loss: 0.7260 (1.35 sec/step)
# INFO:tensorflow:global step 132: loss: 0.9845 (1.34 sec/step)
# INFO:tensorflow:global step 133: loss: 1.3979 (1.35 sec/step)
# INFO:tensorflow:global step 134: loss: 0.7196 (1.34 sec/step)
# INFO:tensorflow:global step 135: loss: 0.7650 (1.34 sec/step)
# INFO:tensorflow:global step 136: loss: 0.8591 (1.34 sec/step)
# INFO:tensorflow:global step 137: loss: 0.9204 (1.34 sec/step)
# INFO:tensorflow:global step 138: loss: 1.0699 (1.34 sec/step)
# INFO:tensorflow:global step 139: loss: 1.0175 (1.34 sec/step)
# INFO:tensorflow:global step 140: loss: 1.1354 (1.34 sec/step)
# INFO:tensorflow:global step 141: loss: 0.9789 (1.35 sec/step)
# INFO:tensorflow:global step 142: loss: 1.3135 (1.34 sec/step)
# INFO:tensorflow:global step 143: loss: 1.1484 (1.34 sec/step)
# INFO:tensorflow:global step 144: loss: 0.8558 (1.34 sec/step)
# INFO:tensorflow:global step 145: loss: 0.9672 (1.34 sec/step)
# INFO:tensorflow:global step 146: loss: 0.9316 (1.34 sec/step)
# INFO:tensorflow:global step 147: loss: 0.8129 (1.34 sec/step)
# INFO:tensorflow:global step 148: loss: 1.2562 (1.34 sec/step)
# INFO:tensorflow:global step 149: loss: 0.8622 (1.36 sec/step)
# INFO:tensorflow:global step 150: loss: 1.3454 (1.36 sec/step)
# INFO:tensorflow:global step 151: loss: 1.1451 (1.36 sec/step)
# INFO:tensorflow:global step 152: loss: 1.0921 (1.36 sec/step)
# INFO:tensorflow:global step 153: loss: 1.0548 (1.36 sec/step)
# INFO:tensorflow:global step 154: loss: 0.9647 (1.35 sec/step)
# INFO:tensorflow:global step 155: loss: 1.1194 (1.36 sec/step)
# INFO:tensorflow:global step 156: loss: 1.3288 (1.36 sec/step)
# INFO:tensorflow:global step 157: loss: 0.8584 (1.36 sec/step)
# INFO:tensorflow:global step 158: loss: 1.0138 (1.35 sec/step)
# INFO:tensorflow:global step 159: loss: 0.9089 (1.36 sec/step)
# INFO:tensorflow:global step 160: loss: 1.0700 (1.36 sec/step)
# INFO:tensorflow:global step 161: loss: 0.7481 (1.36 sec/step)
# INFO:tensorflow:global step 162: loss: 0.9438 (1.36 sec/step)
# INFO:tensorflow:global step 163: loss: 1.0156 (1.35 sec/step)
# INFO:tensorflow:global step 164: loss: 1.5708 (1.36 sec/step)
# INFO:tensorflow:global step 165: loss: 0.9233 (1.36 sec/step)
# INFO:tensorflow:global_step/sec: 0.725057
# INFO:tensorflow:global step 166: loss: 1.1905 (1.36 sec/step)
# INFO:tensorflow:global step 167: loss: 1.4320 (1.37 sec/step)
# INFO:tensorflow:global step 168: loss: 1.0348 (1.36 sec/step)
# INFO:tensorflow:global step 169: loss: 0.9751 (1.36 sec/step)
# INFO:tensorflow:global step 170: loss: 0.8239 (1.36 sec/step)
# INFO:tensorflow:global step 171: loss: 0.8565 (1.36 sec/step)
# INFO:tensorflow:global step 172: loss: 1.1222 (1.36 sec/step)
# INFO:tensorflow:global step 173: loss: 1.2150 (1.41 sec/step)
# INFO:tensorflow:global step 174: loss: 1.0924 (1.38 sec/step)
# INFO:tensorflow:global step 175: loss: 0.8367 (1.37 sec/step)
# INFO:tensorflow:global step 176: loss: 0.7466 (1.38 sec/step)
# INFO:tensorflow:global step 177: loss: 0.9769 (1.37 sec/step)
# INFO:tensorflow:global step 178: loss: 0.8528 (1.38 sec/step)
# INFO:tensorflow:global step 179: loss: 1.1450 (1.36 sec/step)
# INFO:tensorflow:global step 180: loss: 1.0026 (1.34 sec/step)
# INFO:tensorflow:global step 181: loss: 1.0882 (1.36 sec/step)
# INFO:tensorflow:global step 182: loss: 0.9448 (1.35 sec/step)
# INFO:tensorflow:global step 183: loss: 0.9048 (1.36 sec/step)
# INFO:tensorflow:global step 184: loss: 1.2383 (1.34 sec/step)
# INFO:tensorflow:global step 185: loss: 0.8021 (1.35 sec/step)
# INFO:tensorflow:global step 186: loss: 0.7114 (1.36 sec/step)
# INFO:tensorflow:global step 187: loss: 1.3445 (1.34 sec/step)
# INFO:tensorflow:global step 188: loss: 0.9044 (1.36 sec/step)
# INFO:tensorflow:global step 189: loss: 0.7797 (1.35 sec/step)
# INFO:tensorflow:global step 190: loss: 0.9997 (1.35 sec/step)
# INFO:tensorflow:global step 191: loss: 0.7767 (1.35 sec/step)
# INFO:tensorflow:global step 192: loss: 0.7215 (1.37 sec/step)
# INFO:tensorflow:global step 193: loss: 0.7828 (1.38 sec/step)
# INFO:tensorflow:global step 194: loss: 1.2790 (1.39 sec/step)
# INFO:tensorflow:global step 195: loss: 1.0832 (1.37 sec/step)
# INFO:tensorflow:global step 196: loss: 1.0908 (1.41 sec/step)
# INFO:tensorflow:global step 197: loss: 1.5933 (1.37 sec/step)
# INFO:tensorflow:global step 198: loss: 0.8015 (1.36 sec/step)
# INFO:tensorflow:global step 199: loss: 1.1789 (1.36 sec/step)
# INFO:tensorflow:global step 200: loss: 0.9514 (1.36 sec/step)
# INFO:tensorflow:global step 201: loss: 0.8294 (1.36 sec/step)
# INFO:tensorflow:global step 202: loss: 0.9893 (1.36 sec/step)
# INFO:tensorflow:global step 203: loss: 1.0591 (1.36 sec/step)
# INFO:tensorflow:global step 204: loss: 0.7624 (1.36 sec/step)
# INFO:tensorflow:global step 205: loss: 0.9264 (1.36 sec/step)
# INFO:tensorflow:global step 206: loss: 0.8867 (1.37 sec/step)
# INFO:tensorflow:global step 207: loss: 0.8839 (1.36 sec/step)
# INFO:tensorflow:global step 208: loss: 1.1423 (1.36 sec/step)
# INFO:tensorflow:global step 209: loss: 1.0840 (1.36 sec/step)
# INFO:tensorflow:global step 210: loss: 0.9073 (1.36 sec/step)
# INFO:tensorflow:global step 211: loss: 1.0080 (1.36 sec/step)
# INFO:tensorflow:global step 212: loss: 1.2363 (1.36 sec/step)
# INFO:tensorflow:global step 213: loss: 0.6396 (1.36 sec/step)
# INFO:tensorflow:global step 214: loss: 1.2095 (1.36 sec/step)
# INFO:tensorflow:global step 215: loss: 0.9049 (1.36 sec/step)
# INFO:tensorflow:global step 216: loss: 0.8646 (1.36 sec/step)
# INFO:tensorflow:global step 217: loss: 1.4536 (1.36 sec/step)
# INFO:tensorflow:global step 218: loss: 0.8838 (1.36 sec/step)
# INFO:tensorflow:global step 219: loss: 0.6493 (1.36 sec/step)
# INFO:tensorflow:global step 220: loss: 0.5990 (1.36 sec/step)
# INFO:tensorflow:global step 221: loss: 0.7170 (1.36 sec/step)
# INFO:tensorflow:global step 222: loss: 1.2589 (1.36 sec/step)
# INFO:tensorflow:global step 223: loss: 1.2521 (1.36 sec/step)
# INFO:tensorflow:global step 224: loss: 0.5804 (1.36 sec/step)
# INFO:tensorflow:global step 225: loss: 1.3224 (1.36 sec/step)
# INFO:tensorflow:global step 226: loss: 1.3125 (1.36 sec/step)
# INFO:tensorflow:global step 227: loss: 1.8420 (1.36 sec/step)
# INFO:tensorflow:global step 228: loss: 1.2413 (1.36 sec/step)
# INFO:tensorflow:global step 229: loss: 1.0366 (1.36 sec/step)
# INFO:tensorflow:global step 230: loss: 0.7483 (1.36 sec/step)
# INFO:tensorflow:global step 231: loss: 0.7695 (1.36 sec/step)
# INFO:tensorflow:global step 232: loss: 1.6604 (1.36 sec/step)
# INFO:tensorflow:global step 233: loss: 1.0595 (1.36 sec/step)
# INFO:tensorflow:global step 234: loss: 0.6796 (1.36 sec/step)
# INFO:tensorflow:global step 235: loss: 0.7720 (1.36 sec/step)
# INFO:tensorflow:global step 236: loss: 0.9160 (1.57 sec/step)
# INFO:tensorflow:global step 237: loss: 0.9261 (1.34 sec/step)
# INFO:tensorflow:global step 238: loss: 0.8252 (1.34 sec/step)
# INFO:tensorflow:global step 239: loss: 1.0937 (1.34 sec/step)
# INFO:tensorflow:global step 240: loss: 1.0177 (1.35 sec/step)
# INFO:tensorflow:global step 241: loss: 1.2502 (1.34 sec/step)
# INFO:tensorflow:global step 242: loss: 1.1086 (1.33 sec/step)
# INFO:tensorflow:global step 243: loss: 0.9616 (1.33 sec/step)
# INFO:tensorflow:global step 244: loss: 1.0058 (1.34 sec/step)
# INFO:tensorflow:global step 245: loss: 1.0788 (1.34 sec/step)
# INFO:tensorflow:global step 246: loss: 1.0791 (1.33 sec/step)
# INFO:tensorflow:global step 247: loss: 1.0186 (1.33 sec/step)
# INFO:tensorflow:global step 248: loss: 0.6910 (1.34 sec/step)
# INFO:tensorflow:global step 249: loss: 1.0875 (1.34 sec/step)
# INFO:tensorflow:global step 250: loss: 0.9274 (1.34 sec/step)
# INFO:tensorflow:global_step/sec: 0.708334
# INFO:tensorflow:global step 251: loss: 0.7865 (1.34 sec/step)
# INFO:tensorflow:global step 252: loss: 1.2194 (1.34 sec/step)
# INFO:tensorflow:global step 253: loss: 0.9751 (1.34 sec/step)
# INFO:tensorflow:global step 254: loss: 0.7122 (1.33 sec/step)
# INFO:tensorflow:global step 255: loss: 1.7988 (1.34 sec/step)
# INFO:tensorflow:global step 256: loss: 1.4906 (1.34 sec/step)
# INFO:tensorflow:global step 257: loss: 0.8665 (1.34 sec/step)
# INFO:tensorflow:global step 258: loss: 0.9512 (1.36 sec/step)
# INFO:tensorflow:global step 259: loss: 1.1875 (1.36 sec/step)
# INFO:tensorflow:global step 260: loss: 1.3245 (1.36 sec/step)
# INFO:tensorflow:global step 261: loss: 0.8158 (1.36 sec/step)
# INFO:tensorflow:global step 262: loss: 0.9016 (1.35 sec/step)
# INFO:tensorflow:global step 263: loss: 0.9172 (1.37 sec/step)
# INFO:tensorflow:global step 264: loss: 0.6913 (1.37 sec/step)
# INFO:tensorflow:global step 265: loss: 0.7701 (1.36 sec/step)
# INFO:tensorflow:global step 266: loss: 0.9368 (1.36 sec/step)
# INFO:tensorflow:global step 267: loss: 0.9433 (1.36 sec/step)
# INFO:tensorflow:global step 268: loss: 0.9325 (1.36 sec/step)
# INFO:tensorflow:global step 269: loss: 1.0733 (1.36 sec/step)
# INFO:tensorflow:global step 270: loss: 1.0121 (1.36 sec/step)
# INFO:tensorflow:global step 271: loss: 1.0903 (1.36 sec/step)
# INFO:tensorflow:global step 272: loss: 0.6223 (1.36 sec/step)
# INFO:tensorflow:global step 273: loss: 1.2665 (1.36 sec/step)
# INFO:tensorflow:global step 274: loss: 0.8244 (1.36 sec/step)
# INFO:tensorflow:global step 275: loss: 0.6625 (1.36 sec/step)
# INFO:tensorflow:global step 276: loss: 1.3750 (1.36 sec/step)
# INFO:tensorflow:global step 277: loss: 1.8384 (1.36 sec/step)
# INFO:tensorflow:global step 278: loss: 0.8268 (1.36 sec/step)
# INFO:tensorflow:global step 279: loss: 1.0335 (1.36 sec/step)
# INFO:tensorflow:global step 280: loss: 0.8645 (1.36 sec/step)
# INFO:tensorflow:global step 281: loss: 1.1098 (1.36 sec/step)
# INFO:tensorflow:global step 282: loss: 0.8360 (1.36 sec/step)
# INFO:tensorflow:global step 283: loss: 0.8633 (1.36 sec/step)
# INFO:tensorflow:global step 284: loss: 1.0680 (1.36 sec/step)
# INFO:tensorflow:global step 285: loss: 0.6394 (1.36 sec/step)
# INFO:tensorflow:global step 286: loss: 1.0193 (1.35 sec/step)
# INFO:tensorflow:global step 287: loss: 0.9739 (1.36 sec/step)
# INFO:tensorflow:global step 288: loss: 1.8194 (1.36 sec/step)
# INFO:tensorflow:global step 289: loss: 0.7684 (1.36 sec/step)
# INFO:tensorflow:global step 290: loss: 1.0865 (1.36 sec/step)
# INFO:tensorflow:global step 291: loss: 0.8606 (1.36 sec/step)
# INFO:tensorflow:global step 292: loss: 1.0282 (1.36 sec/step)
# INFO:tensorflow:global step 293: loss: 1.3994 (1.36 sec/step)
# INFO:tensorflow:global step 294: loss: 0.7196 (1.36 sec/step)
# INFO:tensorflow:global step 295: loss: 0.7326 (1.36 sec/step)
# INFO:tensorflow:global step 296: loss: 0.8483 (1.36 sec/step)
# INFO:tensorflow:global step 297: loss: 1.4857 (1.36 sec/step)
# INFO:tensorflow:global step 298: loss: 0.9404 (1.36 sec/step)
# INFO:tensorflow:global step 299: loss: 1.3482 (1.36 sec/step)
# INFO:tensorflow:global step 300: loss: 0.8814 (1.36 sec/step)
# INFO:tensorflow:global step 301: loss: 0.9020 (1.36 sec/step)
# INFO:tensorflow:global step 302: loss: 0.9065 (1.36 sec/step)
# INFO:tensorflow:global step 303: loss: 1.1097 (1.36 sec/step)
# INFO:tensorflow:global step 304: loss: 1.0864 (1.36 sec/step)
# INFO:tensorflow:global step 305: loss: 0.9156 (1.36 sec/step)
# INFO:tensorflow:global step 306: loss: 1.3192 (1.36 sec/step)
# INFO:tensorflow:global step 307: loss: 0.7008 (1.36 sec/step)
# INFO:tensorflow:global step 308: loss: 0.7965 (1.36 sec/step)
# INFO:tensorflow:global step 309: loss: 0.9350 (1.36 sec/step)
# INFO:tensorflow:global step 310: loss: 0.9460 (1.36 sec/step)
# INFO:tensorflow:global step 311: loss: 0.8188 (1.36 sec/step)
# INFO:tensorflow:global step 312: loss: 0.6811 (1.36 sec/step)
# INFO:tensorflow:global step 313: loss: 0.9035 (1.36 sec/step)
# INFO:tensorflow:global step 314: loss: 0.7951 (1.36 sec/step)
# INFO:tensorflow:global step 315: loss: 0.9047 (1.36 sec/step)
# INFO:tensorflow:global step 316: loss: 0.6769 (1.35 sec/step)
# INFO:tensorflow:global step 317: loss: 1.1238 (1.36 sec/step)
# INFO:tensorflow:global step 318: loss: 0.8633 (1.36 sec/step)
# INFO:tensorflow:global step 319: loss: 0.8044 (1.36 sec/step)
# INFO:tensorflow:global step 320: loss: 0.6447 (1.36 sec/step)
# INFO:tensorflow:global step 321: loss: 1.2400 (1.36 sec/step)
# INFO:tensorflow:global step 322: loss: 0.9787 (1.36 sec/step)
# INFO:tensorflow:global step 323: loss: 0.7472 (1.36 sec/step)
# INFO:tensorflow:global step 324: loss: 0.8984 (1.36 sec/step)
# INFO:tensorflow:global step 325: loss: 0.9337 (1.36 sec/step)
# INFO:tensorflow:global step 326: loss: 0.8565 (1.35 sec/step)
# INFO:tensorflow:global step 327: loss: 1.0060 (1.36 sec/step)
# INFO:tensorflow:global step 328: loss: 1.1015 (1.36 sec/step)
# INFO:tensorflow:global step 329: loss: 0.7536 (1.36 sec/step)
# INFO:tensorflow:global step 330: loss: 0.6880 (1.36 sec/step)
# INFO:tensorflow:global step 331: loss: 0.9952 (1.36 sec/step)
# INFO:tensorflow:global step 332: loss: 1.4044 (1.37 sec/step)
# INFO:tensorflow:global step 333: loss: 1.1630 (1.37 sec/step)
# INFO:tensorflow:global step 334: loss: 0.8531 (1.38 sec/step)
# INFO:tensorflow:global step 335: loss: 1.1895 (1.38 sec/step)
# INFO:tensorflow:global_step/sec: 0.708331
# INFO:tensorflow:global step 336: loss: 1.0119 (1.38 sec/step)
# INFO:tensorflow:global step 337: loss: 0.9918 (1.38 sec/step)
# INFO:tensorflow:global step 338: loss: 1.0884 (1.38 sec/step)
# INFO:tensorflow:global step 339: loss: 0.8188 (1.38 sec/step)
# INFO:tensorflow:global step 340: loss: 0.5868 (1.38 sec/step)
# INFO:tensorflow:global step 341: loss: 0.8784 (1.38 sec/step)
# INFO:tensorflow:global step 342: loss: 0.9273 (1.37 sec/step)
# INFO:tensorflow:global step 343: loss: 1.3975 (1.38 sec/step)
# INFO:tensorflow:global step 344: loss: 1.1315 (1.38 sec/step)
# INFO:tensorflow:global step 345: loss: 1.3715 (1.38 sec/step)
# INFO:tensorflow:global step 346: loss: 0.8558 (1.37 sec/step)
# INFO:tensorflow:global step 347: loss: 0.8550 (1.37 sec/step)
# INFO:tensorflow:global step 348: loss: 0.9125 (1.38 sec/step)
# INFO:tensorflow:global step 349: loss: 0.7997 (1.38 sec/step)
# INFO:tensorflow:global step 350: loss: 1.0170 (1.38 sec/step)
# INFO:tensorflow:global step 351: loss: 1.1765 (1.38 sec/step)
# INFO:tensorflow:global step 352: loss: 0.8988 (1.38 sec/step)
# INFO:tensorflow:global step 353: loss: 1.1850 (1.38 sec/step)
# INFO:tensorflow:global step 354: loss: 1.2718 (1.38 sec/step)
# INFO:tensorflow:global step 355: loss: 0.8102 (1.38 sec/step)
# INFO:tensorflow:global step 356: loss: 1.1057 (1.37 sec/step)
# INFO:tensorflow:global step 357: loss: 0.9617 (1.38 sec/step)
# INFO:tensorflow:global step 358: loss: 1.2893 (1.38 sec/step)
# INFO:tensorflow:global step 359: loss: 1.7807 (1.37 sec/step)
# INFO:tensorflow:global step 360: loss: 0.8793 (1.38 sec/step)
# INFO:tensorflow:global step 361: loss: 0.9875 (1.38 sec/step)
# INFO:tensorflow:global step 362: loss: 1.2987 (1.38 sec/step)
# INFO:tensorflow:global step 363: loss: 1.0522 (1.38 sec/step)
# INFO:tensorflow:global step 364: loss: 0.9883 (1.37 sec/step)
# INFO:tensorflow:global step 365: loss: 1.0429 (1.38 sec/step)
# INFO:tensorflow:global step 366: loss: 0.8861 (1.38 sec/step)
# INFO:tensorflow:global step 367: loss: 0.7352 (1.38 sec/step)
# INFO:tensorflow:global step 368: loss: 0.6743 (1.38 sec/step)
# INFO:tensorflow:global step 369: loss: 0.8630 (1.38 sec/step)
# INFO:tensorflow:global step 370: loss: 0.8383 (1.38 sec/step)
# INFO:tensorflow:global step 371: loss: 0.7494 (1.38 sec/step)
# INFO:tensorflow:global step 372: loss: 0.9027 (1.38 sec/step)
# INFO:tensorflow:global step 373: loss: 0.8011 (1.38 sec/step)
# INFO:tensorflow:global step 374: loss: 0.6761 (1.38 sec/step)
# INFO:tensorflow:global step 375: loss: 1.1660 (1.37 sec/step)
# INFO:tensorflow:global step 376: loss: 0.6144 (1.38 sec/step)
# INFO:tensorflow:global step 377: loss: 1.2856 (1.37 sec/step)
# INFO:tensorflow:global step 378: loss: 1.1093 (1.37 sec/step)
# INFO:tensorflow:global step 379: loss: 1.0808 (1.38 sec/step)
# INFO:tensorflow:global step 380: loss: 1.5586 (1.38 sec/step)
# INFO:tensorflow:global step 381: loss: 1.0717 (1.38 sec/step)
# INFO:tensorflow:global step 382: loss: 1.1413 (1.38 sec/step)
# INFO:tensorflow:global step 383: loss: 0.7831 (1.38 sec/step)
# INFO:tensorflow:global step 384: loss: 1.0456 (1.37 sec/step)
# INFO:tensorflow:global step 385: loss: 0.7430 (1.38 sec/step)
# INFO:tensorflow:global step 386: loss: 0.9669 (1.38 sec/step)
# INFO:tensorflow:global step 387: loss: 1.2269 (1.38 sec/step)
# INFO:tensorflow:global step 388: loss: 0.9616 (1.38 sec/step)
# INFO:tensorflow:global step 389: loss: 0.9096 (1.38 sec/step)
# INFO:tensorflow:global step 390: loss: 0.9642 (1.38 sec/step)
# INFO:tensorflow:global step 391: loss: 0.9173 (1.38 sec/step)
# INFO:tensorflow:global step 392: loss: 1.0618 (1.38 sec/step)
# INFO:tensorflow:global step 393: loss: 0.7595 (1.38 sec/step)
# INFO:tensorflow:global step 394: loss: 0.6707 (1.38 sec/step)
# INFO:tensorflow:global step 395: loss: 0.7687 (1.38 sec/step)
# INFO:tensorflow:global step 396: loss: 0.8068 (1.38 sec/step)
# INFO:tensorflow:global step 397: loss: 0.9587 (1.38 sec/step)
# INFO:tensorflow:global step 398: loss: 1.2500 (1.38 sec/step)
# INFO:tensorflow:global step 399: loss: 0.6493 (1.38 sec/step)
# INFO:tensorflow:global step 400: loss: 0.7844 (1.38 sec/step)
# INFO:tensorflow:global step 401: loss: 1.1941 (1.38 sec/step)
# INFO:tensorflow:global step 402: loss: 0.7275 (1.37 sec/step)
# INFO:tensorflow:global step 403: loss: 0.6708 (1.38 sec/step)
# INFO:tensorflow:global step 404: loss: 0.6296 (1.38 sec/step)
# INFO:tensorflow:global step 405: loss: 0.5890 (1.38 sec/step)
# INFO:tensorflow:global step 406: loss: 0.5788 (1.38 sec/step)
# INFO:tensorflow:global step 407: loss: 0.5736 (1.38 sec/step)
# INFO:tensorflow:global step 408: loss: 1.1263 (1.38 sec/step)
# INFO:tensorflow:global step 409: loss: 0.6675 (1.38 sec/step)
# INFO:tensorflow:global step 410: loss: 0.8447 (1.38 sec/step)
# INFO:tensorflow:global step 411: loss: 0.6598 (1.38 sec/step)
# INFO:tensorflow:global step 412: loss: 1.0503 (1.38 sec/step)
# INFO:tensorflow:global step 413: loss: 1.1622 (1.38 sec/step)
# INFO:tensorflow:global step 414: loss: 1.0295 (1.37 sec/step)
# INFO:tensorflow:global step 415: loss: 0.8637 (1.37 sec/step)
# INFO:tensorflow:global step 416: loss: 0.8869 (1.37 sec/step)
# INFO:tensorflow:global step 417: loss: 0.9149 (1.37 sec/step)
# INFO:tensorflow:global step 418: loss: 1.3775 (1.38 sec/step)
# INFO:tensorflow:global step 419: loss: 1.6399 (1.38 sec/step)
# INFO:tensorflow:global step 420: loss: 1.0848 (1.38 sec/step)
# INFO:tensorflow:global_step/sec: 0.708333
# INFO:tensorflow:global step 421: loss: 1.6481 (1.38 sec/step)
# INFO:tensorflow:global step 422: loss: 0.8322 (1.37 sec/step)
# INFO:tensorflow:global step 423: loss: 0.8693 (1.38 sec/step)
# INFO:tensorflow:global step 424: loss: 0.7955 (1.37 sec/step)
# INFO:tensorflow:global step 425: loss: 0.7352 (1.37 sec/step)
# INFO:tensorflow:global step 426: loss: 0.8380 (1.36 sec/step)
# INFO:tensorflow:global step 427: loss: 1.0796 (1.37 sec/step)
# INFO:tensorflow:global step 428: loss: 0.7562 (1.38 sec/step)
# INFO:tensorflow:global step 429: loss: 0.9396 (1.37 sec/step)
# INFO:tensorflow:global step 430: loss: 0.9168 (1.36 sec/step)
# INFO:tensorflow:global step 431: loss: 0.7795 (4.68 sec/step)
# INFO:tensorflow:global step 432: loss: 0.8401 (1.24 sec/step)
# INFO:tensorflow:global step 433: loss: 0.7245 (1.24 sec/step)
# INFO:tensorflow:global step 434: loss: 0.6750 (1.24 sec/step)
# INFO:tensorflow:global step 435: loss: 1.1773 (1.23 sec/step)
# INFO:tensorflow:global step 436: loss: 0.8439 (1.28 sec/step)
# INFO:tensorflow:global step 437: loss: 1.0217 (1.31 sec/step)
# INFO:tensorflow:global step 438: loss: 0.9807 (1.31 sec/step)
# INFO:tensorflow:global step 439: loss: 1.1791 (1.33 sec/step)
# INFO:tensorflow:global step 440: loss: 0.5821 (1.33 sec/step)
# INFO:tensorflow:global step 441: loss: 1.3554 (1.34 sec/step)
# INFO:tensorflow:global step 442: loss: 1.1499 (1.34 sec/step)
# INFO:tensorflow:global step 443: loss: 1.2130 (1.36 sec/step)
# INFO:tensorflow:global step 444: loss: 0.8884 (1.35 sec/step)
# INFO:tensorflow:global step 445: loss: 0.7881 (1.35 sec/step)
# INFO:tensorflow:global step 446: loss: 0.7955 (1.35 sec/step)
# INFO:tensorflow:global step 447: loss: 1.3481 (1.35 sec/step)
# INFO:tensorflow:global step 448: loss: 0.7091 (1.35 sec/step)
# INFO:tensorflow:global step 449: loss: 0.7908 (1.36 sec/step)
# INFO:tensorflow:global step 450: loss: 1.1445 (1.35 sec/step)
# INFO:tensorflow:global step 451: loss: 1.1401 (1.35 sec/step)
# INFO:tensorflow:global step 452: loss: 0.9165 (1.35 sec/step)
# INFO:tensorflow:global step 453: loss: 1.6706 (1.36 sec/step)
# INFO:tensorflow:global step 454: loss: 1.1269 (1.36 sec/step)
# INFO:tensorflow:global step 455: loss: 1.2776 (1.35 sec/step)
# INFO:tensorflow:global step 456: loss: 0.6260 (1.36 sec/step)
# INFO:tensorflow:global step 457: loss: 0.8455 (1.35 sec/step)
# INFO:tensorflow:global step 458: loss: 0.9355 (1.35 sec/step)
# INFO:tensorflow:global step 459: loss: 0.9599 (1.36 sec/step)
# INFO:tensorflow:global step 460: loss: 1.1360 (1.35 sec/step)
# INFO:tensorflow:global step 461: loss: 1.1712 (1.35 sec/step)
# INFO:tensorflow:global step 462: loss: 1.1693 (1.35 sec/step)
# INFO:tensorflow:global step 463: loss: 1.0666 (1.35 sec/step)
# INFO:tensorflow:global step 464: loss: 0.9748 (1.36 sec/step)
# INFO:tensorflow:global step 465: loss: 0.6301 (1.36 sec/step)
# INFO:tensorflow:global step 466: loss: 0.9007 (1.36 sec/step)
# INFO:tensorflow:global step 467: loss: 0.9592 (1.36 sec/step)
# INFO:tensorflow:global step 468: loss: 0.9184 (1.36 sec/step)
# INFO:tensorflow:global step 469: loss: 0.9142 (1.37 sec/step)
# INFO:tensorflow:global step 470: loss: 1.0503 (1.36 sec/step)
# INFO:tensorflow:global step 471: loss: 0.8717 (1.36 sec/step)
# INFO:tensorflow:global step 472: loss: 0.7706 (1.36 sec/step)
# INFO:tensorflow:global step 473: loss: 1.0324 (1.36 sec/step)
# INFO:tensorflow:global step 474: loss: 1.2929 (1.36 sec/step)
# INFO:tensorflow:global step 475: loss: 0.8115 (1.36 sec/step)
# INFO:tensorflow:global step 476: loss: 1.0124 (1.36 sec/step)
# INFO:tensorflow:global step 477: loss: 0.9634 (1.36 sec/step)
# INFO:tensorflow:global step 478: loss: 0.7067 (1.36 sec/step)
# INFO:tensorflow:global step 479: loss: 0.6405 (1.38 sec/step)
# INFO:tensorflow:global step 480: loss: 0.6826 (1.38 sec/step)
# INFO:tensorflow:global step 481: loss: 0.9777 (1.38 sec/step)
# INFO:tensorflow:global step 482: loss: 0.8425 (1.38 sec/step)
# INFO:tensorflow:global step 483: loss: 1.1875 (1.37 sec/step)
# INFO:tensorflow:global step 484: loss: 0.8396 (1.38 sec/step)
# INFO:tensorflow:global step 485: loss: 0.8183 (1.37 sec/step)
# INFO:tensorflow:global step 486: loss: 0.9296 (1.38 sec/step)
# INFO:tensorflow:global step 487: loss: 0.9362 (1.38 sec/step)
# INFO:tensorflow:global step 488: loss: 1.0876 (1.38 sec/step)
# INFO:tensorflow:global step 489: loss: 0.6454 (1.38 sec/step)
# INFO:tensorflow:global step 490: loss: 0.6852 (1.38 sec/step)
# INFO:tensorflow:global step 491: loss: 1.3271 (1.38 sec/step)
# INFO:tensorflow:global step 492: loss: 0.8883 (1.38 sec/step)
# INFO:tensorflow:global step 493: loss: 0.8019 (1.38 sec/step)
# INFO:tensorflow:global step 494: loss: 0.6867 (1.38 sec/step)
# INFO:tensorflow:global step 495: loss: 1.1795 (1.38 sec/step)
# INFO:tensorflow:global step 496: loss: 0.7247 (1.37 sec/step)
# INFO:tensorflow:global step 497: loss: 0.7968 (1.38 sec/step)
# INFO:tensorflow:global step 498: loss: 1.2630 (1.38 sec/step)
# INFO:tensorflow:global step 499: loss: 0.6772 (1.38 sec/step)
# INFO:tensorflow:global step 500: loss: 0.9011 (1.38 sec/step)
# INFO:tensorflow:global step 501: loss: 0.7192 (1.38 sec/step)
# INFO:tensorflow:global_step/sec: 0.674932
# INFO:tensorflow:global step 502: loss: 0.7418 (1.37 sec/step)
# INFO:tensorflow:global step 503: loss: 0.6865 (1.38 sec/step)
# INFO:tensorflow:global step 504: loss: 0.7990 (1.38 sec/step)
# INFO:tensorflow:global step 505: loss: 0.7066 (1.38 sec/step)
# INFO:tensorflow:global step 506: loss: 1.4242 (1.38 sec/step)
# INFO:tensorflow:global step 507: loss: 0.9489 (1.38 sec/step)
# INFO:tensorflow:global step 508: loss: 0.9178 (1.38 sec/step)
# INFO:tensorflow:global step 509: loss: 0.9233 (1.38 sec/step)
# INFO:tensorflow:global step 510: loss: 0.8047 (1.38 sec/step)
# INFO:tensorflow:global step 511: loss: 1.1186 (1.38 sec/step)
# INFO:tensorflow:global step 512: loss: 0.8312 (1.38 sec/step)
# INFO:tensorflow:global step 513: loss: 1.1591 (1.38 sec/step)
# INFO:tensorflow:global step 514: loss: 0.7547 (1.38 sec/step)
# INFO:tensorflow:global step 515: loss: 1.1522 (1.38 sec/step)
# INFO:tensorflow:global step 516: loss: 0.7563 (1.38 sec/step)
# INFO:tensorflow:global step 517: loss: 0.7944 (1.37 sec/step)
# INFO:tensorflow:global step 518: loss: 1.0006 (1.38 sec/step)
# INFO:tensorflow:global step 519: loss: 0.8076 (1.38 sec/step)
# INFO:tensorflow:global step 520: loss: 0.6579 (1.38 sec/step)
# INFO:tensorflow:global step 521: loss: 1.0781 (1.38 sec/step)
# INFO:tensorflow:global step 522: loss: 0.8121 (1.37 sec/step)
# INFO:tensorflow:global step 523: loss: 1.0514 (1.38 sec/step)
# INFO:tensorflow:global step 524: loss: 0.8461 (1.38 sec/step)
# INFO:tensorflow:global step 525: loss: 1.2568 (1.37 sec/step)
# INFO:tensorflow:global step 526: loss: 0.7848 (1.38 sec/step)
# INFO:tensorflow:global step 527: loss: 0.6822 (1.38 sec/step)
# INFO:tensorflow:global step 528: loss: 1.2342 (1.38 sec/step)
# INFO:tensorflow:global step 529: loss: 0.8901 (1.38 sec/step)
# INFO:tensorflow:global step 530: loss: 0.8645 (1.37 sec/step)
# INFO:tensorflow:global step 531: loss: 0.9375 (1.37 sec/step)
# INFO:tensorflow:global step 532: loss: 0.8344 (1.38 sec/step)
# INFO:tensorflow:global step 533: loss: 0.9358 (1.37 sec/step)
# INFO:tensorflow:global step 534: loss: 0.8775 (1.37 sec/step)
# INFO:tensorflow:global step 535: loss: 0.9145 (1.38 sec/step)
# INFO:tensorflow:global step 536: loss: 0.6514 (1.38 sec/step)
# INFO:tensorflow:global step 537: loss: 0.8064 (1.38 sec/step)
# INFO:tensorflow:global step 538: loss: 1.0022 (1.38 sec/step)
# INFO:tensorflow:global step 539: loss: 0.9604 (1.38 sec/step)
# INFO:tensorflow:global step 540: loss: 1.4044 (1.38 sec/step)
# INFO:tensorflow:global step 541: loss: 0.8189 (1.38 sec/step)
# INFO:tensorflow:global step 542: loss: 0.9648 (1.38 sec/step)
# INFO:tensorflow:global step 543: loss: 1.1890 (1.38 sec/step)
# INFO:tensorflow:global step 544: loss: 1.1632 (1.38 sec/step)
# INFO:tensorflow:global step 545: loss: 0.7948 (1.38 sec/step)
# INFO:tensorflow:global step 546: loss: 1.0493 (1.38 sec/step)
# INFO:tensorflow:global step 547: loss: 0.8199 (1.38 sec/step)
# INFO:tensorflow:global step 548: loss: 0.6308 (1.38 sec/step)
# INFO:tensorflow:global step 549: loss: 0.9048 (1.37 sec/step)
# INFO:tensorflow:global step 550: loss: 1.0881 (1.38 sec/step)
# INFO:tensorflow:global step 551: loss: 0.7312 (1.37 sec/step)
# INFO:tensorflow:global step 552: loss: 0.6066 (1.37 sec/step)
# INFO:tensorflow:global step 553: loss: 1.2582 (1.38 sec/step)
# INFO:tensorflow:global step 554: loss: 0.5921 (1.38 sec/step)
# INFO:tensorflow:global step 555: loss: 1.4256 (1.38 sec/step)
# INFO:tensorflow:global step 556: loss: 1.2226 (1.37 sec/step)
# INFO:tensorflow:global step 557: loss: 0.8568 (1.38 sec/step)
# INFO:tensorflow:global step 558: loss: 0.9651 (1.37 sec/step)
# INFO:tensorflow:global step 559: loss: 0.9543 (1.37 sec/step)
# INFO:tensorflow:global step 560: loss: 1.0398 (1.38 sec/step)
# INFO:tensorflow:global step 561: loss: 0.9913 (1.38 sec/step)
# INFO:tensorflow:global step 562: loss: 0.6569 (1.38 sec/step)
# INFO:tensorflow:global step 563: loss: 0.7692 (1.38 sec/step)
# INFO:tensorflow:global step 564: loss: 0.8993 (1.38 sec/step)
# INFO:tensorflow:global step 565: loss: 0.6390 (1.37 sec/step)
# INFO:tensorflow:global step 566: loss: 0.6771 (1.38 sec/step)
# INFO:tensorflow:global step 567: loss: 0.8855 (1.38 sec/step)
# INFO:tensorflow:global step 568: loss: 0.7502 (1.38 sec/step)
# INFO:tensorflow:global step 569: loss: 0.6781 (1.38 sec/step)
# INFO:tensorflow:global step 570: loss: 0.5497 (1.38 sec/step)
# INFO:tensorflow:global step 571: loss: 0.9166 (1.37 sec/step)
# INFO:tensorflow:global step 572: loss: 0.9294 (1.38 sec/step)
# INFO:tensorflow:global step 573: loss: 0.7117 (1.38 sec/step)
# INFO:tensorflow:global step 574: loss: 1.2370 (1.38 sec/step)
# INFO:tensorflow:global step 575: loss: 1.0894 (1.38 sec/step)
# INFO:tensorflow:global step 576: loss: 1.0215 (1.38 sec/step)
# INFO:tensorflow:global step 577: loss: 0.6433 (1.37 sec/step)
# INFO:tensorflow:global step 578: loss: 0.8076 (1.38 sec/step)
# INFO:tensorflow:global step 579: loss: 0.7977 (1.38 sec/step)
# INFO:tensorflow:global step 580: loss: 0.8796 (1.38 sec/step)
# INFO:tensorflow:global step 581: loss: 0.8693 (1.38 sec/step)
# INFO:tensorflow:global step 582: loss: 0.9344 (1.37 sec/step)
# INFO:tensorflow:global step 583: loss: 0.8259 (1.38 sec/step)
# INFO:tensorflow:global step 584: loss: 0.7767 (1.37 sec/step)
# INFO:tensorflow:global step 585: loss: 1.2443 (1.38 sec/step)
# INFO:tensorflow:global step 586: loss: 1.0231 (1.38 sec/step)
# INFO:tensorflow:global_step/sec: 0.708407
# INFO:tensorflow:global step 587: loss: 0.8665 (1.38 sec/step)
# INFO:tensorflow:global step 588: loss: 0.7067 (1.37 sec/step)
# INFO:tensorflow:global step 589: loss: 0.7161 (1.38 sec/step)
# INFO:tensorflow:global step 590: loss: 1.1490 (1.38 sec/step)
# INFO:tensorflow:global step 591: loss: 0.8878 (1.37 sec/step)
# INFO:tensorflow:global step 592: loss: 1.1181 (1.37 sec/step)
# INFO:tensorflow:global step 593: loss: 0.5917 (1.37 sec/step)
# INFO:tensorflow:global step 594: loss: 0.8568 (1.38 sec/step)
# INFO:tensorflow:global step 595: loss: 2.0589 (1.38 sec/step)
# INFO:tensorflow:global step 596: loss: 0.7017 (1.37 sec/step)
# INFO:tensorflow:global step 597: loss: 0.9889 (1.37 sec/step)
# INFO:tensorflow:global step 598: loss: 1.0482 (1.38 sec/step)
# INFO:tensorflow:global step 599: loss: 0.5656 (1.38 sec/step)
# INFO:tensorflow:global step 600: loss: 1.3138 (1.38 sec/step)
# INFO:tensorflow:global step 601: loss: 0.9756 (1.37 sec/step)
# INFO:tensorflow:global step 602: loss: 0.8124 (1.38 sec/step)
# INFO:tensorflow:global step 603: loss: 1.5716 (1.38 sec/step)
# INFO:tensorflow:global step 604: loss: 0.7956 (1.38 sec/step)
# INFO:tensorflow:global step 605: loss: 1.0276 (1.37 sec/step)
# INFO:tensorflow:global step 606: loss: 0.7952 (1.37 sec/step)
# INFO:tensorflow:global step 607: loss: 0.8323 (1.38 sec/step)
# INFO:tensorflow:global step 608: loss: 0.7171 (1.38 sec/step)
# INFO:tensorflow:global step 609: loss: 1.0575 (1.37 sec/step)
# INFO:tensorflow:global step 610: loss: 1.1665 (1.38 sec/step)
# INFO:tensorflow:global step 611: loss: 0.7125 (1.37 sec/step)
# INFO:tensorflow:global step 612: loss: 1.3101 (1.38 sec/step)
# INFO:tensorflow:global step 613: loss: 0.8601 (1.37 sec/step)
# INFO:tensorflow:global step 614: loss: 1.2022 (1.38 sec/step)
# INFO:tensorflow:global step 615: loss: 1.1310 (1.37 sec/step)
# INFO:tensorflow:global step 616: loss: 0.8911 (1.38 sec/step)
# INFO:tensorflow:global step 617: loss: 1.1190 (1.37 sec/step)
# INFO:tensorflow:global step 618: loss: 0.7635 (1.38 sec/step)
# INFO:tensorflow:global step 619: loss: 0.6863 (1.38 sec/step)
# INFO:tensorflow:global step 620: loss: 0.6860 (1.38 sec/step)
# INFO:tensorflow:global step 621: loss: 1.2511 (1.38 sec/step)
# INFO:tensorflow:global step 622: loss: 0.9213 (1.38 sec/step)
# INFO:tensorflow:global step 623: loss: 0.7644 (1.38 sec/step)
# INFO:tensorflow:global step 624: loss: 1.0313 (1.38 sec/step)
# INFO:tensorflow:global step 625: loss: 1.0310 (1.38 sec/step)
# INFO:tensorflow:global step 626: loss: 0.7176 (1.38 sec/step)
# INFO:tensorflow:global step 627: loss: 0.6862 (1.38 sec/step)
# INFO:tensorflow:global step 628: loss: 0.8348 (1.37 sec/step)
# INFO:tensorflow:global step 629: loss: 1.0425 (1.38 sec/step)
# INFO:tensorflow:global step 630: loss: 0.8327 (1.38 sec/step)
# INFO:tensorflow:global step 631: loss: 0.9470 (1.37 sec/step)
# INFO:tensorflow:global step 632: loss: 1.2379 (1.38 sec/step)
# INFO:tensorflow:global step 633: loss: 0.7706 (1.38 sec/step)
# INFO:tensorflow:global step 634: loss: 0.9069 (1.38 sec/step)
# INFO:tensorflow:global step 635: loss: 0.7104 (1.38 sec/step)
# INFO:tensorflow:global step 636: loss: 1.1950 (1.38 sec/step)
# INFO:tensorflow:global step 637: loss: 1.7487 (1.38 sec/step)
# INFO:tensorflow:global step 638: loss: 0.7554 (1.37 sec/step)
# INFO:tensorflow:global step 639: loss: 1.0292 (1.38 sec/step)
# INFO:tensorflow:global step 640: loss: 0.7800 (1.37 sec/step)
# INFO:tensorflow:global step 641: loss: 0.6870 (1.38 sec/step)
# INFO:tensorflow:global step 642: loss: 0.6095 (1.37 sec/step)
# INFO:tensorflow:global step 643: loss: 0.8312 (1.38 sec/step)
# INFO:tensorflow:global step 644: loss: 0.8070 (1.38 sec/step)
# INFO:tensorflow:global step 645: loss: 1.0210 (1.38 sec/step)
# INFO:tensorflow:global step 646: loss: 1.0127 (1.38 sec/step)
# INFO:tensorflow:global step 647: loss: 1.0054 (1.37 sec/step)
# INFO:tensorflow:global step 648: loss: 1.1944 (1.37 sec/step)
# INFO:tensorflow:global step 649: loss: 0.7146 (1.38 sec/step)
# INFO:tensorflow:global step 650: loss: 0.8996 (1.38 sec/step)
# INFO:tensorflow:global step 651: loss: 0.8215 (1.38 sec/step)
# INFO:tensorflow:global step 652: loss: 0.8841 (1.37 sec/step)
# INFO:tensorflow:global step 653: loss: 1.0600 (1.37 sec/step)
# INFO:tensorflow:global step 654: loss: 0.7770 (1.38 sec/step)
# INFO:tensorflow:global step 655: loss: 0.6802 (1.38 sec/step)
# INFO:tensorflow:global step 656: loss: 1.3487 (1.38 sec/step)
# INFO:tensorflow:global step 657: loss: 1.0669 (1.37 sec/step)
# INFO:tensorflow:global step 658: loss: 0.7358 (1.38 sec/step)
# INFO:tensorflow:global step 659: loss: 0.7005 (1.37 sec/step)
# INFO:tensorflow:global step 660: loss: 0.6678 (1.37 sec/step)
# INFO:tensorflow:global step 661: loss: 0.8993 (1.37 sec/step)
# INFO:tensorflow:global step 662: loss: 0.9548 (1.38 sec/step)
# INFO:tensorflow:global step 663: loss: 0.6928 (1.38 sec/step)
# INFO:tensorflow:global step 664: loss: 0.6810 (1.38 sec/step)
# INFO:tensorflow:global step 665: loss: 1.5042 (1.38 sec/step)
# INFO:tensorflow:global step 666: loss: 0.7089 (1.38 sec/step)
# INFO:tensorflow:global step 667: loss: 1.0475 (1.38 sec/step)
# INFO:tensorflow:global step 668: loss: 0.7344 (1.38 sec/step)
# INFO:tensorflow:global step 669: loss: 0.6541 (1.38 sec/step)
# INFO:tensorflow:global step 670: loss: 0.6444 (1.38 sec/step)
# INFO:tensorflow:global_step/sec: 0.699997
# INFO:tensorflow:global step 671: loss: 0.7652 (1.38 sec/step)
# INFO:tensorflow:global step 672: loss: 0.6480 (1.38 sec/step)
# INFO:tensorflow:global step 673: loss: 0.7990 (1.38 sec/step)
# INFO:tensorflow:global step 674: loss: 1.4253 (1.37 sec/step)
# INFO:tensorflow:global step 675: loss: 1.3150 (1.37 sec/step)
# INFO:tensorflow:global step 676: loss: 0.7735 (1.37 sec/step)
# INFO:tensorflow:global step 677: loss: 0.7423 (1.38 sec/step)
# INFO:tensorflow:global step 678: loss: 0.9374 (1.38 sec/step)
# INFO:tensorflow:global step 679: loss: 0.8495 (1.38 sec/step)
# INFO:tensorflow:global step 680: loss: 1.4276 (1.38 sec/step)
# INFO:tensorflow:global step 681: loss: 0.7837 (1.38 sec/step)
# INFO:tensorflow:global step 682: loss: 0.7813 (1.38 sec/step)
# INFO:tensorflow:global step 683: loss: 0.9130 (1.38 sec/step)
# INFO:tensorflow:global step 684: loss: 0.6182 (1.37 sec/step)
# INFO:tensorflow:global step 685: loss: 0.7379 (1.37 sec/step)
# INFO:tensorflow:global step 686: loss: 1.0842 (1.38 sec/step)
# INFO:tensorflow:global step 687: loss: 0.6241 (1.38 sec/step)
# INFO:tensorflow:global step 688: loss: 0.9261 (1.38 sec/step)
# INFO:tensorflow:global step 689: loss: 0.9805 (1.38 sec/step)
# INFO:tensorflow:global step 690: loss: 0.9413 (1.38 sec/step)
# INFO:tensorflow:global step 691: loss: 1.3270 (1.38 sec/step)
# INFO:tensorflow:global step 692: loss: 0.6528 (1.37 sec/step)
# INFO:tensorflow:global step 693: loss: 0.7213 (1.38 sec/step)
# INFO:tensorflow:global step 694: loss: 0.9408 (1.37 sec/step)
# INFO:tensorflow:global step 695: loss: 1.2450 (1.38 sec/step)
# INFO:tensorflow:global step 696: loss: 0.9690 (1.38 sec/step)
# INFO:tensorflow:global step 697: loss: 0.6420 (1.38 sec/step)
# INFO:tensorflow:global step 698: loss: 1.0359 (1.37 sec/step)
# INFO:tensorflow:global step 699: loss: 1.0208 (1.38 sec/step)
# INFO:tensorflow:global step 700: loss: 1.3034 (1.38 sec/step)
# INFO:tensorflow:global step 701: loss: 1.0551 (1.38 sec/step)
# INFO:tensorflow:global step 702: loss: 1.2272 (1.37 sec/step)
# INFO:tensorflow:global step 703: loss: 0.9373 (1.38 sec/step)
# INFO:tensorflow:global step 704: loss: 0.6996 (1.37 sec/step)
# INFO:tensorflow:global step 705: loss: 1.0413 (1.38 sec/step)
# INFO:tensorflow:global step 706: loss: 0.8601 (1.38 sec/step)
# INFO:tensorflow:global step 707: loss: 0.9339 (1.38 sec/step)
# INFO:tensorflow:global step 708: loss: 0.9180 (1.38 sec/step)
# INFO:tensorflow:global step 709: loss: 1.0949 (1.38 sec/step)
# INFO:tensorflow:global step 710: loss: 0.9234 (1.38 sec/step)
# INFO:tensorflow:global step 711: loss: 0.6905 (1.37 sec/step)
# INFO:tensorflow:global step 712: loss: 0.8107 (1.38 sec/step)
# INFO:tensorflow:global step 713: loss: 0.7640 (1.38 sec/step)
# INFO:tensorflow:global step 714: loss: 0.9473 (1.38 sec/step)
# INFO:tensorflow:global step 715: loss: 1.1722 (1.38 sec/step)
# INFO:tensorflow:global step 716: loss: 0.7135 (1.38 sec/step)
# INFO:tensorflow:global step 717: loss: 1.2487 (1.38 sec/step)
# INFO:tensorflow:global step 718: loss: 0.7452 (1.38 sec/step)
# INFO:tensorflow:global step 719: loss: 0.8283 (1.38 sec/step)
# INFO:tensorflow:global step 720: loss: 0.7486 (1.38 sec/step)
# INFO:tensorflow:global step 721: loss: 0.8117 (1.38 sec/step)
# INFO:tensorflow:global step 722: loss: 0.7376 (1.38 sec/step)
# INFO:tensorflow:global step 723: loss: 0.6250 (1.38 sec/step)
# INFO:tensorflow:global step 724: loss: 1.0642 (1.38 sec/step)
# INFO:tensorflow:global step 725: loss: 0.6839 (1.37 sec/step)
# INFO:tensorflow:global step 726: loss: 0.7291 (1.37 sec/step)
# INFO:tensorflow:global step 727: loss: 1.5410 (1.38 sec/step)
# INFO:tensorflow:global step 728: loss: 0.5648 (1.38 sec/step)
# INFO:tensorflow:global step 729: loss: 0.7871 (1.38 sec/step)
# INFO:tensorflow:global step 730: loss: 0.5774 (1.37 sec/step)
# INFO:tensorflow:global step 731: loss: 0.9909 (1.38 sec/step)
# INFO:tensorflow:global step 732: loss: 0.8213 (1.38 sec/step)
# INFO:tensorflow:global step 733: loss: 0.7241 (1.38 sec/step)
# INFO:tensorflow:global step 734: loss: 0.8093 (1.38 sec/step)
# INFO:tensorflow:global step 735: loss: 0.8003 (1.38 sec/step)
# ...
# INFO:tensorflow:global step 2252: loss: 1.1302 (1.37 sec/step)
# INFO:tensorflow:global step 2253: loss: 0.7000 (1.37 sec/step)
# INFO:tensorflow:global step 2254: loss: 0.8063 (1.38 sec/step)
# INFO:tensorflow:global step 2255: loss: 0.6493 (1.37 sec/step)
# INFO:tensorflow:global step 2256: loss: 1.0727 (1.38 sec/step)
# INFO:tensorflow:global step 2257: loss: 1.0075 (1.37 sec/step)
# INFO:tensorflow:global step 2258: loss: 0.8468 (1.37 sec/step)
# INFO:tensorflow:global step 2259: loss: 0.9245 (1.38 sec/step)
# INFO:tensorflow:global step 2260: loss: 0.9365 (1.38 sec/step)
# INFO:tensorflow:global step 2261: loss: 0.7818 (1.37 sec/step)
# INFO:tensorflow:global step 2262: loss: 0.7187 (1.37 sec/step)
# INFO:tensorflow:global step 2263: loss: 0.7009 (1.37 sec/step)
# INFO:tensorflow:global step 2264: loss: 0.7532 (1.37 sec/step)
# INFO:tensorflow:global step 2265: loss: 0.5712 (1.37 sec/step)
# INFO:tensorflow:global step 2266: loss: 0.8245 (1.38 sec/step)
# INFO:tensorflow:global step 2267: loss: 0.9323 (1.38 sec/step)
# INFO:tensorflow:global step 2268: loss: 1.4758 (1.38 sec/step)
# INFO:tensorflow:global step 2269: loss: 0.7442 (1.39 sec/step)
# INFO:tensorflow:global step 2270: loss: 0.7992 (1.37 sec/step)
# INFO:tensorflow:global step 2271: loss: 0.5909 (1.37 sec/step)
# INFO:tensorflow:global step 2272: loss: 0.8333 (1.38 sec/step)
# INFO:tensorflow:global step 2273: loss: 0.7601 (1.38 sec/step)
# INFO:tensorflow:global step 2274: loss: 1.0815 (1.38 sec/step)
# INFO:tensorflow:global step 2275: loss: 0.6847 (1.38 sec/step)
# INFO:tensorflow:global step 2276: loss: 0.9099 (1.38 sec/step)
# INFO:tensorflow:global step 2277: loss: 0.6130 (1.38 sec/step)
# INFO:tensorflow:global step 2278: loss: 0.6668 (1.38 sec/step)
# INFO:tensorflow:global step 2279: loss: 0.5248 (1.38 sec/step)
# INFO:tensorflow:global step 2280: loss: 0.7543 (1.38 sec/step)
# INFO:tensorflow:global step 2281: loss: 0.6731 (1.37 sec/step)
# INFO:tensorflow:global step 2282: loss: 0.5619 (1.37 sec/step)
# INFO:tensorflow:global step 2283: loss: 0.6229 (1.37 sec/step)
# INFO:tensorflow:global step 2284: loss: 1.0861 (1.37 sec/step)
# INFO:tensorflow:global step 2285: loss: 0.7443 (1.37 sec/step)
# INFO:tensorflow:global step 2286: loss: 0.6843 (1.38 sec/step)
# INFO:tensorflow:global step 2287: loss: 0.6907 (1.37 sec/step)
# INFO:tensorflow:global step 2288: loss: 0.9932 (1.38 sec/step)
# INFO:tensorflow:global step 2289: loss: 1.2140 (1.38 sec/step)
# INFO:tensorflow:global step 2290: loss: 0.6223 (1.39 sec/step)
# INFO:tensorflow:global step 2291: loss: 0.7421 (1.38 sec/step)
# INFO:tensorflow:global step 2292: loss: 0.9414 (1.37 sec/step)
# INFO:tensorflow:global step 2293: loss: 1.1693 (1.38 sec/step)
# INFO:tensorflow:global step 2294: loss: 0.6158 (1.37 sec/step)
# INFO:tensorflow:global step 2295: loss: 0.8990 (1.38 sec/step)
# INFO:tensorflow:global step 2296: loss: 0.7054 (1.37 sec/step)
# INFO:tensorflow:global step 2297: loss: 0.8866 (1.38 sec/step)
# INFO:tensorflow:global step 2298: loss: 0.6947 (1.37 sec/step)
# INFO:tensorflow:global step 2299: loss: 0.7121 (1.37 sec/step)
# INFO:tensorflow:global step 2300: loss: 0.6544 (1.38 sec/step)
# INFO:tensorflow:global step 2301: loss: 1.4218 (1.38 sec/step)
# INFO:tensorflow:global step 2302: loss: 0.8204 (1.38 sec/step)
# INFO:tensorflow:global step 2303: loss: 0.5931 (1.38 sec/step)
# INFO:tensorflow:global step 2304: loss: 0.6296 (1.37 sec/step)
# INFO:tensorflow:global step 2305: loss: 1.0913 (1.38 sec/step)
# INFO:tensorflow:global step 2306: loss: 0.8932 (1.37 sec/step)
# INFO:tensorflow:global step 2307: loss: 0.6024 (1.38 sec/step)
# INFO:tensorflow:global step 2308: loss: 0.9174 (1.38 sec/step)
# INFO:tensorflow:global step 2309: loss: 0.7335 (1.37 sec/step)
# INFO:tensorflow:global step 2310: loss: 0.5766 (1.37 sec/step)
# INFO:tensorflow:global step 2311: loss: 0.7919 (1.38 sec/step)
# INFO:tensorflow:global step 2312: loss: 0.7375 (1.37 sec/step)
# INFO:tensorflow:global step 2313: loss: 0.6878 (1.37 sec/step)
# INFO:tensorflow:global step 2314: loss: 0.9468 (1.37 sec/step)
# INFO:tensorflow:global step 2315: loss: 0.7506 (1.37 sec/step)
# INFO:tensorflow:global step 2316: loss: 0.6081 (1.37 sec/step)
# INFO:tensorflow:global step 2317: loss: 1.2408 (1.38 sec/step)
# INFO:tensorflow:global step 2318: loss: 1.1532 (1.39 sec/step)
# INFO:tensorflow:global step 2319: loss: 0.7299 (1.39 sec/step)
# INFO:tensorflow:global step 2320: loss: 0.5538 (1.39 sec/step)
# INFO:tensorflow:global step 2321: loss: 0.6605 (1.39 sec/step)
# INFO:tensorflow:global step 2322: loss: 0.5783 (1.39 sec/step)
# INFO:tensorflow:global step 2323: loss: 0.8219 (1.39 sec/step)
# INFO:tensorflow:global step 2324: loss: 0.9019 (1.39 sec/step)
# INFO:tensorflow:global step 2325: loss: 0.6216 (1.39 sec/step)
# INFO:tensorflow:global step 2326: loss: 0.9220 (1.39 sec/step)
# INFO:tensorflow:global step 2327: loss: 0.6271 (1.39 sec/step)
# INFO:tensorflow:global step 2328: loss: 1.1399 (1.39 sec/step)
# INFO:tensorflow:global step 2329: loss: 1.0555 (1.39 sec/step)
# INFO:tensorflow:global step 2330: loss: 0.7513 (1.39 sec/step)
# INFO:tensorflow:global step 2331: loss: 0.5422 (1.39 sec/step)
# INFO:tensorflow:global step 2332: loss: 0.6754 (1.40 sec/step)
# INFO:tensorflow:global step 2333: loss: 0.8142 (1.39 sec/step)
# INFO:tensorflow:global step 2334: loss: 0.8341 (1.39 sec/step)
# INFO:tensorflow:global step 2335: loss: 0.7209 (1.39 sec/step)
# INFO:tensorflow:global step 2336: loss: 1.1843 (1.39 sec/step)
# INFO:tensorflow:global step 2337: loss: 0.5738 (1.39 sec/step)
# INFO:tensorflow:global step 2338: loss: 0.7957 (1.39 sec/step)
# INFO:tensorflow:global step 2339: loss: 0.7776 (1.76 sec/step)
# INFO:tensorflow:global step 2340: loss: 0.8047 (1.34 sec/step)
# INFO:tensorflow:global step 2341: loss: 0.6880 (1.35 sec/step)
# INFO:tensorflow:global step 2342: loss: 0.8246 (1.36 sec/step)
# INFO:tensorflow:global step 2343: loss: 0.7722 (1.38 sec/step)
# INFO:tensorflow:global step 2344: loss: 0.6718 (1.44 sec/step)
# INFO:tensorflow:global step 2345: loss: 0.5471 (1.43 sec/step)
# INFO:tensorflow:global step 2346: loss: 0.7169 (1.40 sec/step)
# INFO:tensorflow:global step 2347: loss: 0.6414 (1.42 sec/step)
# INFO:tensorflow:global step 2348: loss: 1.1287 (1.41 sec/step)
# INFO:tensorflow:global step 2349: loss: 0.6905 (1.39 sec/step)
# INFO:tensorflow:global step 2350: loss: 0.6582 (1.40 sec/step)
# INFO:tensorflow:global step 2351: loss: 0.6332 (1.39 sec/step)
# INFO:tensorflow:global step 2352: loss: 0.6291 (1.40 sec/step)
# INFO:tensorflow:global step 2353: loss: 0.7743 (1.40 sec/step)
# INFO:tensorflow:global step 2354: loss: 0.7876 (1.40 sec/step)
# INFO:tensorflow:global step 2355: loss: 0.6154 (1.40 sec/step)
# INFO:tensorflow:global step 2356: loss: 1.1371 (1.41 sec/step)
# INFO:tensorflow:global step 2357: loss: 1.3674 (1.40 sec/step)
# INFO:tensorflow:global step 2358: loss: 0.7947 (1.40 sec/step)
# INFO:tensorflow:global step 2359: loss: 0.9465 (1.40 sec/step)
# INFO:tensorflow:global step 2360: loss: 0.6661 (1.41 sec/step)
# INFO:tensorflow:global step 2361: loss: 1.0677 (1.39 sec/step)
# INFO:tensorflow:global step 2362: loss: 0.6791 (1.41 sec/step)
# INFO:tensorflow:global step 2363: loss: 0.6328 (1.41 sec/step)
# INFO:tensorflow:global step 2364: loss: 0.9375 (1.39 sec/step)
# INFO:tensorflow:global step 2365: loss: 0.6467 (1.40 sec/step)
# INFO:tensorflow:global step 2366: loss: 0.8229 (1.41 sec/step)
# INFO:tensorflow:global step 2367: loss: 0.6448 (1.40 sec/step)
# INFO:tensorflow:global step 2368: loss: 0.9645 (1.39 sec/step)
# INFO:tensorflow:global step 2369: loss: 0.7829 (1.40 sec/step)
# INFO:tensorflow:global step 2370: loss: 0.9124 (1.39 sec/step)
# INFO:tensorflow:global step 2371: loss: 0.7092 (1.41 sec/step)
# INFO:tensorflow:global step 2372: loss: 0.6780 (1.39 sec/step)
# INFO:tensorflow:global step 2373: loss: 1.0649 (1.40 sec/step)
# INFO:tensorflow:global step 2374: loss: 1.2240 (1.39 sec/step)
# INFO:tensorflow:global step 2375: loss: 0.5484 (1.39 sec/step)
# INFO:tensorflow:global step 2376: loss: 0.7516 (1.40 sec/step)
# INFO:tensorflow:global step 2377: loss: 0.5262 (1.40 sec/step)
# INFO:tensorflow:global step 2378: loss: 0.7848 (1.41 sec/step)
# INFO:tensorflow:global step 2379: loss: 0.6693 (1.40 sec/step)
# INFO:tensorflow:global step 2380: loss: 0.8355 (1.40 sec/step)
# INFO:tensorflow:global step 2381: loss: 0.7108 (1.39 sec/step)
# INFO:tensorflow:global step 2382: loss: 0.7641 (1.39 sec/step)
# INFO:tensorflow:global step 2383: loss: 1.0087 (1.42 sec/step)
# INFO:tensorflow:global step 2384: loss: 0.5675 (1.43 sec/step)
# INFO:tensorflow:global step 2385: loss: 0.6421 (1.40 sec/step)
# INFO:tensorflow:global step 2386: loss: 0.5959 (1.41 sec/step)
# INFO:tensorflow:global step 2387: loss: 0.6877 (1.41 sec/step)
# INFO:tensorflow:global step 2388: loss: 0.8715 (1.43 sec/step)
# INFO:tensorflow:global step 2389: loss: 0.5294 (1.45 sec/step)
# INFO:tensorflow:global step 2390: loss: 0.7003 (1.42 sec/step)
# INFO:tensorflow:global step 2391: loss: 1.2870 (1.42 sec/step)
# INFO:tensorflow:global step 2392: loss: 0.9465 (1.42 sec/step)
# INFO:tensorflow:global step 2393: loss: 0.6016 (1.44 sec/step)
# INFO:tensorflow:global step 2394: loss: 0.6939 (1.43 sec/step)
# INFO:tensorflow:global step 2395: loss: 1.0533 (1.41 sec/step)
# INFO:tensorflow:global step 2396: loss: 0.6750 (1.41 sec/step)
# INFO:tensorflow:global step 2397: loss: 1.0512 (1.42 sec/step)
# INFO:tensorflow:global step 2398: loss: 1.0455 (1.41 sec/step)
# INFO:tensorflow:global step 2399: loss: 0.6991 (1.43 sec/step)
# INFO:tensorflow:global step 2400: loss: 0.6005 (1.44 sec/step)
# INFO:tensorflow:global step 2401: loss: 0.7255 (1.40 sec/step)
# INFO:tensorflow:global step 2402: loss: 0.9237 (1.44 sec/step)
# INFO:tensorflow:global step 2403: loss: 0.7835 (1.41 sec/step)
# INFO:tensorflow:global step 2404: loss: 0.9674 (1.41 sec/step)
# INFO:tensorflow:global step 2405: loss: 0.7164 (1.44 sec/step)
# INFO:tensorflow:global step 2406: loss: 0.5408 (1.42 sec/step)
# INFO:tensorflow:global step 2407: loss: 0.8820 (1.49 sec/step)
# INFO:tensorflow:global step 2408: loss: 0.7444 (1.47 sec/step)
# INFO:tensorflow:global step 2409: loss: 0.6131 (1.42 sec/step)
# INFO:tensorflow:global step 2410: loss: 0.5352 (1.42 sec/step)
# INFO:tensorflow:global step 2411: loss: 0.5292 (1.46 sec/step)
# INFO:tensorflow:global step 2412: loss: 1.4366 (1.50 sec/step)
# INFO:tensorflow:global step 2413: loss: 0.6518 (1.49 sec/step)
# INFO:tensorflow:global step 2414: loss: 0.5487 (1.52 sec/step)
# INFO:tensorflow:global step 2415: loss: 0.9484 (1.52 sec/step)
# INFO:tensorflow:global step 2416: loss: 0.8220 (1.47 sec/step)
# INFO:tensorflow:global step 2417: loss: 0.7395 (1.43 sec/step)
# INFO:tensorflow:global step 2418: loss: 0.7794 (1.43 sec/step)
# INFO:tensorflow:global step 2419: loss: 0.7888 (1.42 sec/step)
# INFO:tensorflow:global step 2420: loss: 0.7506 (1.40 sec/step)
# INFO:tensorflow:global step 2421: loss: 0.6115 (1.40 sec/step)
# INFO:tensorflow:global step 2422: loss: 0.6319 (1.39 sec/step)
# INFO:tensorflow:global step 2423: loss: 0.5896 (1.41 sec/step)
# INFO:tensorflow:global step 2424: loss: 1.2599 (1.39 sec/step)
# INFO:tensorflow:global step 2425: loss: 0.9659 (1.39 sec/step)
# INFO:tensorflow:global step 2426: loss: 0.7979 (1.41 sec/step)
# INFO:tensorflow:global step 2427: loss: 0.5376 (1.40 sec/step)
# INFO:tensorflow:global step 2428: loss: 1.0782 (1.40 sec/step)
# INFO:tensorflow:global step 2429: loss: 0.7179 (1.40 sec/step)
# INFO:tensorflow:global step 2430: loss: 0.9123 (1.40 sec/step)
# INFO:tensorflow:global step 2431: loss: 0.5596 (1.41 sec/step)
# INFO:tensorflow:global step 2432: loss: 0.7427 (1.42 sec/step)
# INFO:tensorflow:global step 2433: loss: 0.5571 (1.40 sec/step)
# INFO:tensorflow:global step 2434: loss: 0.6172 (1.40 sec/step)
# INFO:tensorflow:global step 2435: loss: 0.6961 (1.42 sec/step)
# INFO:tensorflow:global step 2436: loss: 1.1346 (1.42 sec/step)
# INFO:tensorflow:global step 2437: loss: 0.6892 (1.40 sec/step)
# INFO:tensorflow:global step 2438: loss: 0.5482 (1.40 sec/step)
# INFO:tensorflow:global step 2439: loss: 0.5840 (1.41 sec/step)
# INFO:tensorflow:global step 2440: loss: 0.4934 (1.43 sec/step)
# INFO:tensorflow:global step 2441: loss: 0.9387 (1.40 sec/step)
# INFO:tensorflow:global step 2442: loss: 0.6315 (1.45 sec/step)
# INFO:tensorflow:global step 2443: loss: 0.6655 (1.44 sec/step)
# INFO:tensorflow:global step 2444: loss: 0.7491 (1.40 sec/step)
# INFO:tensorflow:global step 2445: loss: 0.5848 (1.47 sec/step)
# INFO:tensorflow:global step 2446: loss: 0.6981 (1.41 sec/step)
# INFO:tensorflow:global step 2447: loss: 0.8811 (1.40 sec/step)
# INFO:tensorflow:global step 2448: loss: 0.8116 (1.39 sec/step)
# INFO:tensorflow:global step 2449: loss: 0.6640 (1.45 sec/step)
# INFO:tensorflow:global step 2450: loss: 0.9646 (1.41 sec/step)
# INFO:tensorflow:global step 2451: loss: 0.5022 (1.40 sec/step)
# INFO:tensorflow:global step 2452: loss: 1.1629 (1.39 sec/step)
# INFO:tensorflow:global step 2453: loss: 0.6185 (1.40 sec/step)
# INFO:tensorflow:global step 2454: loss: 1.0659 (1.40 sec/step)
# INFO:tensorflow:global step 2455: loss: 0.7068 (1.41 sec/step)
# INFO:tensorflow:global step 2456: loss: 0.7246 (1.48 sec/step)
# INFO:tensorflow:global step 2457: loss: 0.7332 (1.43 sec/step)
# INFO:tensorflow:global step 2458: loss: 0.6935 (1.47 sec/step)
# INFO:tensorflow:global step 2459: loss: 0.9516 (1.42 sec/step)
# INFO:tensorflow:global step 2460: loss: 0.7547 (1.43 sec/step)
# INFO:tensorflow:global step 2461: loss: 0.6023 (1.41 sec/step)
# INFO:tensorflow:global step 2462: loss: 0.9566 (1.47 sec/step)
# INFO:tensorflow:global step 2463: loss: 0.8849 (1.43 sec/step)
# INFO:tensorflow:global step 2464: loss: 0.7834 (1.40 sec/step)
# INFO:tensorflow:global step 2465: loss: 0.8125 (1.39 sec/step)
# INFO:tensorflow:global step 2466: loss: 0.6052 (1.40 sec/step)
# INFO:tensorflow:global step 2467: loss: 0.5684 (1.44 sec/step)
# INFO:tensorflow:global step 2468: loss: 0.7123 (1.50 sec/step)
# INFO:tensorflow:global step 2469: loss: 0.7038 (1.39 sec/step)
# INFO:tensorflow:global step 2470: loss: 1.0123 (1.41 sec/step)
# INFO:tensorflow:global step 2471: loss: 0.6239 (1.46 sec/step)
# INFO:tensorflow:global step 2472: loss: 0.6329 (1.39 sec/step)
# INFO:tensorflow:global step 2473: loss: 0.9800 (1.42 sec/step)
# INFO:tensorflow:global step 2474: loss: 0.7240 (1.42 sec/step)
# INFO:tensorflow:global step 2475: loss: 1.2526 (1.44 sec/step)
# INFO:tensorflow:global step 2476: loss: 0.8532 (1.45 sec/step)
# INFO:tensorflow:global step 2477: loss: 0.5581 (1.40 sec/step)
# INFO:tensorflow:global step 2478: loss: 0.6513 (1.43 sec/step)
# INFO:tensorflow:global step 2479: loss: 1.0899 (1.42 sec/step)
# INFO:tensorflow:global step 2480: loss: 0.8797 (1.43 sec/step)
# INFO:tensorflow:global step 2481: loss: 0.6403 (1.40 sec/step)
# INFO:tensorflow:global step 2482: loss: 0.7942 (1.44 sec/step)
# INFO:tensorflow:global step 2483: loss: 0.7008 (1.43 sec/step)
# INFO:tensorflow:global step 2484: loss: 0.7357 (1.41 sec/step)
# INFO:tensorflow:global step 2485: loss: 0.9445 (1.40 sec/step)
# INFO:tensorflow:global step 2486: loss: 0.6083 (1.42 sec/step)
# INFO:tensorflow:global step 2487: loss: 0.7502 (1.39 sec/step)
# INFO:tensorflow:global step 2488: loss: 0.6779 (1.39 sec/step)
# INFO:tensorflow:global step 2489: loss: 0.6649 (1.39 sec/step)
# INFO:tensorflow:global step 2490: loss: 0.5376 (1.39 sec/step)
# INFO:tensorflow:global step 2491: loss: 0.5801 (1.40 sec/step)
# INFO:tensorflow:global step 2492: loss: 0.6990 (1.39 sec/step)
# INFO:tensorflow:global step 2493: loss: 0.7744 (1.47 sec/step)
# INFO:tensorflow:global step 2494: loss: 1.0572 (1.40 sec/step)
# INFO:tensorflow:global step 2495: loss: 0.7346 (1.40 sec/step)
# INFO:tensorflow:global step 2496: loss: 0.5807 (1.41 sec/step)
# INFO:tensorflow:global step 2497: loss: 0.5386 (1.39 sec/step)
# INFO:tensorflow:global step 2498: loss: 0.6607 (1.39 sec/step)
# INFO:tensorflow:global step 2499: loss: 0.7243 (3.17 sec/step)
# INFO:tensorflow:global step 2500: loss: 0.6103 (1.29 sec/step)
# INFO:tensorflow:global step 2501: loss: 0.7229 (1.24 sec/step)
# INFO:tensorflow:global step 2502: loss: 0.7941 (1.30 sec/step)
# INFO:tensorflow:global step 2503: loss: 0.5311 (1.34 sec/step)
# INFO:tensorflow:global step 2504: loss: 0.6862 (1.41 sec/step)
